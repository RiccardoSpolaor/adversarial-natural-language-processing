# %% [markdown]
# Train on 26800 samples, validate on 6700 samples
# Epoch 1/10
# 26800/26800 - 20s - loss: 0.4219 - acc: 0.7965 - val_loss: 0.2945 - val_acc: 0.8787
# Epoch 2/10
# 26800/26800 - 17s - loss: 0.2860 - acc: 0.8800 - val_loss: 0.2624 - val_acc: 0.8894
# Epoch 3/10
# 26800/26800 - 17s - loss: 0.2485 - acc: 0.9000 - val_loss: 0.2413 - val_acc: 0.9024
# Epoch 4/10
# 26800/26800 - 17s - loss: 0.2182 - acc: 0.9138 - val_loss: 0.2309 - val_acc: 0.9025
# Epoch 5/10
# 26800/26800 - 18s - loss: 0.1835 - acc: 0.9284 - val_loss: 0.2226 - val_acc: 0.9100
# Epoch 6/10
# 26800/26800 - 18s - loss: 0.1555 - acc: 0.9407 - val_loss: 0.2238 - val_acc: 0.9103
# Epoch 7/10
# 26800/26800 - 17s - loss: 0.1289 - acc: 0.9520 - val_loss: 0.2259 - val_acc: 0.9103
# Epoch 8/10
# 26800/26800 - 17s - loss: 0.1064 - acc: 0.9621 - val_loss: 0.2254 - val_acc: 0.9166
# Epoch 9/10
# 26800/26800 - 17s - loss: 0.0702 - acc: 0.9780 - val_loss: 0.2319 - val_acc: 0.9163
# Epoch 10/10
# 26800/26800 - 17s - loss: 0.0626 - acc: 0.9810 - val_loss: 0.2377 - val_acc: 0.9154

# %%
training_accuracy = [0.7965, 0.8800, 0.9000, 0.9138, 0.9284, 0.9407, 0.9520, 0.9621, 0.9780, 0.9810]
training_loss = [0.4219, 0.2860, 0.2485, 0.2182, 0.1835, 0.1555, 0.1289, 0.1064, 0.0702, 0.0626]
validation_accuracy = [0.8787, 0.8894, 0.9024, 0.9025, 0.9100, 0.9103, 0.9103, 0.9166, 0.9163, 0.9154]
validation_loss = [0.2945, 0.2624, 0.2413, 0.2309, 0.2226, 0.2238, 0.2259, 0.2254, 0.2319, 0.2377]

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(training_accuracy) + 1)
plt.plot(epochs, [e*100 for e in training_accuracy], 'o--', label='Training Accuracy')
plt.plot(epochs, [e*100 for e in validation_accuracy], 'o--', label='Validation Accuracy')
plt.title('Accuracy dei Training e Validation Data Sample')
plt.legend()
plt.xlabel('epochs')
plt.xticks(range(1,11))
plt.ylabel('accuracy (%)')
plt.grid(True)
plt.show()

# %%
plt.plot(epochs, training_loss, 'o--', label='Training Loss Score')
plt.plot(epochs, validation_loss, 'o--', label='Validation Loss Score')
plt.title('Loss Score dei Training e Validation Data Sample')
plt.legend()
plt.xlabel('epochs')
plt.xticks(range(1,11))
plt.ylabel('loss score')
plt.grid(True)
plt.figure(figsize=(15,10))
plt.show()

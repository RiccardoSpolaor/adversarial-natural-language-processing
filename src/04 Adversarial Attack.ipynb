# %% [markdown]
# <center>
#
# # Adversarial Natural Language Processing
#
# ## 04 Adversarial Attack
# ### Riccardo Spolaor (864877)
#
# </center>

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Setting the seeds for deterministic results

# %%
from utils.seed_setter import set_seed
set_seed()

# %% [markdown]
# ## Adversarial Attack
# ### Selecting  the Reviews to Attack
# Firstly an array of reviews is selected. For demonstation purposes just short reviews (500 characters max) are considered. The average review length is of about 1,279 characters. An *attack list* is then created. It contains reviews which are correctly classified from the Sentiment Analysis model that can be queried in a Black-Box system. Reviews which are already misclassified by the model are added to an *adversarial list*.

# %%
import pickle,os

with open(os.path.join('./pickle_data/train_test_data/test_data.pickle'), 'rb') as f:
    x_test, y_test = pickle.load(f)
f.close()

# %%
print('Average length of a review:')
sum(map(len,x_test))/len(x_test)
# Out:
# Average length of a review:
# 1279.084303030303

# %%
from utils.black_box import BlackBox
black_box = BlackBox()

# %%
all_preds = black_box.predict_all(x_test)

# %%
adversarial_list = []

attack_list = []

for sent, lab, pred in list(zip(x_test, y_test, all_preds)):
        if round(pred) == lab and len(sent) < 500:
            attack_list += [(sent,lab)]
        elif round(pred) != lab and len(sent) < 500:
            adversarial_list += [(sent,lab)]

# %%
print('Length of the Attack List:')
len(attack_list)
# Out:
# Length of the Attack List:
# 1610

# %%
print('Length of the list of already misclassified reviews:')
len(adversarial_list)
# Out:
# Length of the list of already misclassified reviews:
# 144

# %%
attack_list[:3]
# Out:
# [('This film could cure sleep disorders, thats how bad it is. The story dragged, and the bad guy is not that scary. You will not even see this one on TBS reruns. This film made me wonder about Chuck film choices. He work on a real dog with this one.',
#   0),
#  ("The trailers get you to the movie, but the movie just wasn't worth my 8.50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they hadn't added this one to their resume's. To be honest, the book is better..",
#   0),
#  ('The message of this movie is "personality is more important than beauty". Jeanine Garofalo is supposed to be the "ugly duckling", but the funny thing is that she\'s not at all ugly (actually she\'s a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the "ugly duckling" was really unattractive? When will Hollywood stop with this hypocrisy?In my opinion, despite the message that it wants to convey, this movie is simply ridiculous.',
#   0)]

# %%
print('Accuracy for the attack list:')
black_box.evaluate([sent for sent, lab in attack_list], [lab for sent, lab in attack_list])
# Out:
# Accuracy for the attack list:
# 1610/1610 [==============================] - 4s 3ms/sample - loss: 0.0466 - acc: 1.0000
# [0.0465955188139255, 1.0]

# %%
print('Accuracy for the adversarial list:')
black_box.evaluate([sent for sent, lab in adversarial_list], [lab for sent, lab in adversarial_list])
# Out:
# Accuracy for the adversarial list:
# 144/144 [==============================] - 0s 3ms/sample - loss: 2.2604 - acc: 0.0000e+00
# [2.2603875266181097, 0.0]

# %% [markdown]
# ### Genetic Optimization Attack Algorithm
# The genetic attack algorithm's code is shown below. It creates a population of altered reviews each generation by substituting single words of the reviews of the previous population. It uses the *Words Distance Matrix* and the *Google One Billion Words Language Model* to select the best substitute candidates of a word at each perturbation. At the beginning the population of altered reviews is generated by perturbing the original one `__max_words` times. If a review of this population is an Adversarial Example it is returned from the algorithm. The next generation children reviews are created by random sampling with probability two parent reviews and by choosing each word from one or another at random. The `__max_children` best children are selected and each one of them is perturbed `__max_words` times. If one of these children reviews is an Adversarial Example it is then returned from the function. The process is repeated and if the algorithm doesn't create an Adversarial Example in `__max_gens` generations the attack fails. When a perturbation occurs stopwords, previously changed words and Named-Entites aren't considered for substitution.

# %%
import string
import re
import os
import numpy as np
import pickle
import licensed_scripts.lm_1b_eval as google_language_model_utils
import nltk
from utils.black_box import BlackBox
import time

nltk.download('maxent_ne_chunker', quiet = True)
nltk.download('words', quiet = True)

class Attacker(object):
    
    def __init__ (self):
        with open(os.path.join('./pickle_data/attack_utils/tokens_dictionary.pickle'), 'rb') as f:
            tokens_dictionary, inverse_tokens_dictionary = pickle.load(f)
            self.__tokens_dictionary = tokens_dictionary
            self.__inverse_tokens_dictionary = inverse_tokens_dictionary
        f.close()
        
        self.__black_box = BlackBox()
        self.__distance_matrix = np.load(os.path.join('./numpy_files/distance_matrix.npy'))
        self.__google_lm = google_language_model_utils.LM()
        self.__stopwords = nltk.corpus.stopwords.words('english')
        self.__sentence_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
        self.__tree_bank_word_tokenizer = nltk.tokenize.TreebankWordTokenizer()
        
        latin_similar = "’'‘ÆÐƎƏƐƔĲŊŒẞÞǷȜæðǝəɛɣĳŋœĸſßþƿȝĄƁÇĐƊĘĦĮƘŁØƠŞȘŢȚŦŲƯY̨Ƴąɓçđɗęħįƙłøơşșţțŧųưy̨ƴÁÀÂÄǍĂĀÃÅǺĄÆǼǢƁĆĊĈČÇĎḌĐƊÐÉÈĖÊËĚĔĒĘẸƎƏƐĠĜǦĞĢƔáàâäǎăāãåǻąæǽǣɓćċĉčçďḍđɗðéèėêëěĕēęẹǝəɛġĝǧğģɣĤḤĦIÍÌİÎÏǏĬĪĨĮỊĲĴĶƘĹĻŁĽĿʼNŃN̈ŇÑŅŊÓÒÔÖǑŎŌÕŐỌØǾƠŒĥḥħıíìiîïǐĭīĩįịĳĵķƙĸĺļłľŀŉńn̈ňñņŋóòôöǒŏōõőọøǿơœŔŘŖŚŜŠŞȘṢẞŤŢṬŦÞÚÙÛÜǓŬŪŨŰŮŲỤƯẂẀŴẄǷÝỲŶŸȲỸƳŹŻŽẒŕřŗſśŝšşșṣßťţṭŧþúùûüǔŭūũűůųụưẃẁŵẅƿýỳŷÿȳỹƴźżžẓ"
        safe_characters = string.ascii_letters + string.digits + latin_similar + ' '
        safe_characters += "'"
        self.__safe_characters = safe_characters
        
        self.__max_words = 5 
        self.__top_neighbours = 8 
        self.__top_lm = 4
        self.__max_gens = 15
        self.__max_children = 2
        self.__max_pop_members = 5
        
        
    def __handle_contractions(self, sentence):
        sentence = self.__tree_bank_word_tokenizer.tokenize(sentence)
        return ' '.join(sentence)
    
    def __preprocess_sentence(self, sentence):
        chars = set(w for w in sentence)
        symbols = [c for c in chars if not c in self.__safe_characters]
        if(len(symbols) == 0):
            new_sentence = sentence[:]
        for symbol in symbols:
            new_sentence = sentence.replace(symbol, ' ' + symbol + ' ')
        new_sentence = self.__handle_contractions(new_sentence)
        return new_sentence
    
    def __split_review(self, review):
        sentences = self.__sentence_tokenizer.tokenize(review)
        labels = [None] * len(sentences)
        for index, sentence in enumerate(sentences):
            sentences[index] = self.__preprocess_sentence(sentence)
            sentences[index] = nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sentences[index])))
            labels[index] = [None] * len(sentences[index])
            for i, chunk in enumerate(sentences[index]):
                if hasattr(chunk, 'label'):
                    labels[index][i] = 1
                    sentences[index][i] = ' '.join(c[0] for c in chunk)
                else:
                    labels[index][i] = 0
                    sentences[index][i] = chunk[0]
        return sentences, labels
            
    def __most_similar(self, word, delta = 0.5, num_words = 20):
        try:
            index = self.__tokens_dictionary[word]
        except:
            return []

        if (index > self.__distance_matrix.shape[0]):
            return []

        dist_order = np.argsort(self.__distance_matrix[index,:])[1:num_words+1]
        dist_list = self.__distance_matrix[index][dist_order]

        mask = np.ones_like(dist_list)
        mask = np.where(dist_list < delta)
        return [self.__inverse_tokens_dictionary[index] for index in dist_order[mask]]         
    
    def __rejoin_review(self, sentences):
        new_sentences = sentences[:]
        for i, sent in enumerate (new_sentences):
            new_sentence = ' '.join(sent)
            new_sentence = re.sub(r' ([^A-Za-z0-9])', r'\1', new_sentence)
            new_sentences[i] = new_sentence
        return ' '.join(new_sentences)
    
    def __perturb(self, sentences, word_index, neighbours, y_target, changed_words_list = []):
        
        prefix = ' '.join(sentences[word_index[0]][ : word_index[1]])
        suffix = ' '.join(sentences[word_index[0]][word_index[1]+1 : -1])
        
        lm_preds = self.__google_lm.get_words_probs(
            prefix, 
            neighbours[ : min(self.__top_neighbours, len(neighbours))], 
            suffix
        )
        
        score_list = []
        for adv_w in np.argsort(lm_preds)[- min(self.__top_lm, len(lm_preds)) : ]: 
            adv_sentences = sentences[:]
            adv_splitted_text = adv_sentences[word_index[0]][:]
            adv_splitted_text[word_index[1]] = neighbours[adv_w]
            adv_sentences[word_index[0]] = adv_splitted_text
            adv_review = self.__rejoin_review(adv_sentences)
            score = self.__black_box.predict_sentiment(adv_review)
            score_list += [(adv_sentences, score, changed_words_list + [word_index])]
            
        adv_reviews_sorted =  sorted(score_list, key=lambda x: x[1])    
        
        
        if y_target == 0:
            return adv_reviews_sorted[0]
            
        else:
            return adv_reviews_sorted[-1]
        
        
    def __crossover(self, parent1, parent2):
        parent1_copy = parent1[0]
        parent2_copy = parent2[0]
        changed_word_list = []
        for i in range(len(parent1_copy)):
            for j in range(len(parent1_copy[i])):
                if np.random.uniform() < 0.5:
                    parent1_copy[i][j] = parent2_copy[i][j]
                    if (i,j) in parent2[2]:
                        changed_word_list += [(i,j)]
                elif (i,j) in parent2[2]:
                    changed_word_list += [(i,j)]
        score = self.__black_box.predict_sentiment(self.__rejoin_review(parent1_copy))
        return parent1_copy, score, changed_word_list
    
    def __get_neighbours_dictionary(self, sentences, labels):
        neighbours_dictionary = {}
        for sent_idx, sent in enumerate(sentences):
            for word_idx, word in enumerate(sent):
                if labels[sent_idx][word_idx] == 1:
                    neighbours_dictionary[(sent_idx, word_idx)] = []
                else:
                    neighbours_dictionary[(sent_idx, word_idx)] = self.__most_similar(
                        word = word.lower(), delta = 0.5, num_words = 50
                    )

        return neighbours_dictionary
    
    def __get_words_to_change(self, neighbours_dictionary, sentences, changed_word_list = []):
        neighbours_length = {key: len(value) for key, value in neighbours_dictionary.items()}

        for key in neighbours_length.keys():
            if sentences[key[0]][key[1]].lower() in self.__stopwords or key in changed_word_list:
                neighbours_length[key] = 0

        length_sum = sum(neighbours_length.values())

        if length_sum == 0:
            return None
        
        neighbours_length = {key: value/length_sum for key, value in neighbours_length.items()}

        probabilities = list(neighbours_length.values())

        random_choice_size = min(len(np.nonzero(probabilities)[0]), self.__max_words)
        
        return np.random.choice(
            len(neighbours_length.keys()), size = random_choice_size, replace = False, p = probabilities
        )
        
    
        
    def attack (self, x_orig, y_orig):
        
        attack_start_time = time.time()
        
        y_target = int(not y_orig)
        sentences, labels = self.__split_review(x_orig)
        
        neighbours_dictionary = self.__get_neighbours_dictionary(sentences, labels)
        words_to_change = self.__get_words_to_change(neighbours_dictionary, sentences)
        
        if words_to_change is None:
            return None
        
        print('Original sentence: \n' + x_orig)
        print('Starting Score: {}; Original Label: {}; Target Label: {}\n'.format(
            self.__black_box.predict_sentiment(x_orig), y_orig, y_target
        ))
        
        print('Generating population... \n')
        
        generation_start_time = time.time()

        population = []
        for index in words_to_change:
            new_member = self.__perturb(
                sentences, 
                list(neighbours_dictionary.keys())[index], 
                neighbours_dictionary[list(neighbours_dictionary.keys())[index]], 
                y_target
            )
            
            if round(new_member[1]) == y_target:
                print('ATTACK SUCCESS!!!\n')
                final_sentence = self.__rejoin_review(new_member[0])
                print('Final adversarial sentence:\n {} \n Score: {}\n'.format(
                    self.__rejoin_review(new_member[0]), new_member[1]
                ))
                print('%total_time = {} seconds\n\n'.format(int(time.time() - attack_start_time)))
                return final_sentence
            
            population += [new_member]

        for i in range(self.__max_gens):

            if len(population) == 0:
                print('ATTACK FAILED...\n')
                print('%total_time = {} seconds\n\n'.format(int(time.time() - attack_start_time)))
                return None
            
            print('Generation #{}: \n'.format(i+1))
            
            sorted_population =  sorted(population, key=lambda x: x[1])    


            if y_target == 0:
                best_attack = sorted_population[0]
                sorted_population = sorted_population[ : min(self.__max_pop_members, len(sorted_population))]

            else:
                best_attack = sorted_population[-1]
                sorted_population = sorted_population[- min(self.__max_pop_members, len(sorted_population)) : ]
                
            print('Best Adversarial:\n {} \n Score: {}\n'.format(self.__rejoin_review(best_attack[0]), best_attack[1]))
            
            print('%generation_time = {} seconds\n'.format(int(time.time() - generation_start_time)))
        

            if y_target == 1:
                pop_scores = np.array([score for review, score, _ in sorted_population])
            else:
                pop_scores = np.array([1 - score for review, score, _ in sorted_population])
                
            logits = np.exp(pop_scores / 0.3)
            selection_probabilities = logits / np.sum(logits)
                
            parent_list_1 = np.random.choice(
                len(sorted_population), size=len(sorted_population), p=selection_probabilities)
            parent_list_2 = np.random.choice(
                len(sorted_population), size=len(sorted_population), p=selection_probabilities)
            
            children = [self.__crossover(
                sorted_population[parent_list_1[i]], 
                sorted_population[parent_list_2[i]]
            ) for i in range(len(sorted_population))]
            
            sorted_children =  sorted(children, key=lambda x: x[1])    
            
            if y_target == 0:
                sorted_children = sorted_children[ : min(self.__max_children, len(sorted_children))]

            else:
                sorted_children = sorted_children[- min(self.__max_children, len(sorted_children)) : ]
            
            perturbated_children = []
            
            print('Regenerating population... \n')
            
            generation_start_time = time.time()
            
            for child in sorted_children:
                
                sentences = child[0]
                
                neighbours_dictionary = self.__get_neighbours_dictionary(sentences, labels)
                words_to_change = self.__get_words_to_change(neighbours_dictionary, sentences, child[2])
                
                if words_to_change is None:
                    words_to_change = self.__get_words_to_change(neighbours_dictionary, sentences)
        
                if words_to_change is None:
                    continue

                for index in words_to_change:
                    new_member = self.__perturb(
                        sentences, 
                        list(neighbours_dictionary.keys())[index], 
                        neighbours_dictionary[list(neighbours_dictionary.keys())[index]], 
                        y_target,
                        child[1]
                    )
                    
                    
                    
                    if round(new_member[1]) == y_target:
                        print('ATTACK SUCCESS!!!\n')
                        final_sentence = self.__rejoin_review(new_member[0])
                        print('Final adversarial sentence:\n {} \n Score: {}\n'.format(
                            self.__rejoin_review(new_member[0]), new_member[1]
                        ))
                        print('%total_time = {} seconds\n\n'.format(int(time.time() - attack_start_time)))
                        return final_sentence

                    perturbated_children += [new_member]

            population = [best_attack] + perturbated_children
        
        print('ATTACK FAILED...\n')
        print('%total_time = {} seconds\n\n'.format(int(time.time() - attack_start_time)))
        return None

# %%
attacker = Attacker()
# Out:
# LM vocab loading done
# Recovering graph.
# INFO:tensorflow:Recovering Graph google_language_model\graph-2016-09-10.pbtxt
# Recovering checkpoint google_language_model\ckpt-*

# %% [markdown]
# ### Testing
# The algorithm process is tested on 25 reviews.

# %%
final_list = []

BATCH_SIZE = 25

for i in range(BATCH_SIZE):
    print('####################ATTACK {}/{}:####################'.format(i+1, BATCH_SIZE))
    new_review = attacker.attack(attack_list[i][0], attack_list[i][1])
    if new_review is None:
        new_review = attack_list[i][0]
    final_list += [(new_review, attack_list[i][1])]
# Out:
# ####################ATTACK 1/25:####################
# Original sentence:
# This film could cure sleep disorders, thats how bad it is. The story dragged, and the bad guy is not that scary. You will not even see this one on TBS reruns. This film made me wonder about Chuck film choices. He work on a real dog with this one.
# Starting Score: 0.04802941903471947; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  This film could cure sleep disorders, thats how bad it is. The story dragged, and the bad guy is not that scary. You will not even see this one on TBS reruns. This film delivered me wonder about Chuck film choices. He work on a real dog with this one.
#  Score: 0.11358830332756042
#
# %generation_time = 145 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  This film could cure sleep disorders, thats how bad it is. The story dragged, and the bad guy is not that scary. You will not even see this one on TBS reruns. This film delivered me wonder about Chuck film choices. He work on a real dog with this one.
#  Score: 0.11358830332756042
#
# %generation_time = 282 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  This movies could cure sleep disorders, dont how bad it is. The story dragged, and the naughty guy is not that scary. You will not even see this one on TBS reruns. This film delivered me wonder about Chuck film choices. He work on a real dog with this one.
#  Score: 0.6101425886154175
#
# %total_time = 459 seconds
#
#
# ####################ATTACK 2/25:####################
# Original sentence:
# The trailers get you to the movie, but the movie just wasn't worth my 8.50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they hadn't added this one to their resume's. To be honest, the book is better..
# Starting Score: 0.0786469578742981; Original Label: 0; Target Label: 1
#
# Generating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  The trailers get you to the movie, but the movie just was n't worth my 8. 50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they had n't added this one to their resume's. To be honest, the book is enhanced..
#  Score: 0.5412546992301941
#
# %total_time = 28 seconds
#
#
# ####################ATTACK 3/25:####################
# Original sentence:
# The message of this movie is "personality is more important than beauty". Jeanine Garofalo is supposed to be the "ugly duckling", but the funny thing is that she's not at all ugly (actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the "ugly duckling" was really unattractive? When will Hollywood stop with this hypocrisy?In my opinion, despite the message that it wants to convey, this movie is simply ridiculous.
# Starting Score: 0.001881183939985931; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  The message of this movie is`` personality is more important than beauty``. Jeanine Garofalo is supposed to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` ugly duckling`` was really unattractive? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is simply absurd.
#  Score: 0.0037010409869253635
#
# %generation_time = 141 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  The message of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` ugly duckling`` was really unattractive? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is simply grotesque.
#  Score: 0.013106878846883774
#
# %generation_time = 283 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` ugly duckling`` was really unattractive? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is sheer grotesque.
#  Score: 0.09158763289451599
#
# %generation_time = 280 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` ugly duckling`` was really repellant? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is purely grotesque.
#  Score: 0.12432479858398438
#
# %generation_time = 283 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who seem like a model).Now, would this movie work if the`` ugly duckling`` was really repellant? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is sheer grotesque.
#  Score: 0.20486609637737274
#
# %generation_time = 282 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` foul duckling`` was really repellant? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is sheer grotesque.
#  Score: 0.2492254674434662
#
# %generation_time = 282 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this cinematic work if the`` foul duckling`` was really repellant? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is pure grotesque.
#  Score: 0.5708771347999573
#
# %total_time = 1642 seconds
#
#
# ####################ATTACK 4/25:####################
# Original sentence:
# Worst pile of drivel to date! Everyone involved with this production should be ashamed of themselves. Not one single element of the movie was anything slightly like an original idea. A first grader telling you a story about nap time is more entertaining.
# Starting Score: 0.00031988113187253475; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  Worst pile of caprice to date! Everyone involved with this production should be ashamed of themselves. Not one single element of the movie was anything slightly like an original idea. A first grader telling you a story about nap time is more entertaining.
#  Score: 0.0014815827598795295
#
# %generation_time = 141 seconds
#
# Regenerating population...
# Generation #2:
#
# Best Adversarial:
#  Worst pile of drivel to date! Everyone involved with this productive should be ashamed of themselves. Not one single element of the movie was anything slightly like an original thoughts. A first grader telling you a story about nap time is more entertaining.
#  Score: 0.0014815827598795295
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  Worst pile of drivel to today! Everyone involved with this productive should be ashamed of themselves. Not one single element of the movie was anything slightly like an original thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.0028019179590046406
#
# %generation_time = 288 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  Worst pile of drivel to today! Everyone involved with this productive should be ashamed of themselves. Not one single element of the cinema was anything slightly like an original thoughts. A first grader telling you a story about nap moment is more hilarious.
#  Score: 0.0040581407956779
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  Worst pile of drivel to today! Everyone involved with this productive should be ashamed of themselves. Not one single aspect of the cinema was anything slightly like an original thoughts. A first grader telling you a tale about nap moment is more hilarious.
#  Score: 0.007096418645232916
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this productive should be ashamed of themselves. Not one single aspect of the cinema was anything slightly like an upfront thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.04958776384592056
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #7:
#
# Best Adversarial:
#  Worst stacked of mania to today! Everyone involved with this productive should be ashamed of themselves. Not one single aspect of the cinema was nothin slightly like an upfront thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.16981834173202515
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #8:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat like an upfront thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.16981834173202515
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #9:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat like an introductory thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.16981834173202515
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #10:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one lonely aspect of the cinema was nothin somewhat love an introductory thoughts. A premiere grader telling you a story about nap time is more hilarious.
#  Score: 0.17262129485607147
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #11:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat like an introductory thoughts. A premiere grader telling you a stories about nap time is more hilarious.
#  Score: 0.17262129485607147
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #12:
#
# Best Adversarial:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat love an upfront thoughts. A premiere grader dis you a stories about pan time is more hilarious.
#  Score: 0.2541144788265228
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat love an introductory idea. A premiere grader dis you a stories about pan time is more hilarious.
#  Score: 0.5170850157737732
#
# %total_time = 3407 seconds
#
#
# ####################ATTACK 5/25:####################
# Original sentence:
# I think that the movie was really good. Subject, acting and Nusrat Fateh ALi Khan's music were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the hands of male-dominated culture, he has neglected Phoolan's character a bit and has focussed more on the violence faced by her.
# Starting Score: 0.8942217826843262; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  I think that the movie was really good. Subject, acting and Nusrat Fateh ALi Khan's music were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the manos of male-dominated culture, he has neglected Phoolan's character a bit and has focussed more on the violence faced by her.
#  Score: 0.804430365562439
#
# %generation_time = 139 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  I think that the movie was really good. Subject, acting and Nusrat Fateh ALi Khan's music were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the hands of male-dominated crop, he has neglected Phoolan's character a bit and has centred more on the assault faced by her.
#  Score: 0.7312291860580444
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  I think that the movies was really good. Subject, acting and Nusrat Fateh ALi Khan's musician were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the manos of male-dominated culture, he has neglected Phoolan's character a bit and has focussed more on the violence faced by her.
#  Score: 0.6467159986495972
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  I think that the movies was frankly good. Subject, acting and Nusrat Fateh ALi Khan's music were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the manos of male-dominated culture, he has omitted Phoolan's character a bit and has focussed more on the violence faced by her.
#  Score: 0.4410463571548462
#
# %total_time = 940 seconds
#
#
# ####################ATTACK 6/25:####################
# Original sentence:
# What more can you ask for? A great screenplay based on one of the finest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great supporting cast. This film takes you on an emotional rollercoaster through humour, sadness, loss and fulfillment. if you are in the theatre it is even more effective. This is a true 10 on the rating scale !
# Starting Score: 0.9984868764877319; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the finest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great supporting cast. This film takes you on an emotional rollercoaster through humour, sadness, loss and fulfillment. if you are in the theatre it is even more efficacious. This is a true 10 on the rating scale!
#  Score: 0.9970404505729675
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the finest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great aid cast. This film takes you on an emotional rollercoaster through humour, sadness, loss and fulfillment. if you are in the theatre it is even more effective. This is a true 10 on the rating scale!
#  Score: 0.9970404505729675
#
# %generation_time = 284 seconds
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the finest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great aid blown. This film takes you on an emotional rollercoaster through humour, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!
#  Score: 0.9874259233474731
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the finest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great aid blown. This film takes you on an emotional rollercoaster through humour, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!
#  Score: 0.9874259233474731
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the nicest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great aid blown. This film takes you on an mentally rollercoaster through humour, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!
#  Score: 0.9390636682510376
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  What more can you ask for? A great screenplay based on one of the nicest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a great aid blown. This film takes you on an emotional rollercoaster through joke, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!
#  Score: 0.8492844700813293
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  What more can you ask for? A great screenplay based on one of the nicest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a grand aid blown. This film takes you on an emotional rollercoaster through travesty, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!
#  Score: 0.4211207926273346
#
# %total_time = 1857 seconds
#
#
# ####################ATTACK 7/25:####################
# Original sentence:
# I vowed a long time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of "Saturday Night Live". I didn't rent "Corky Romano" but I was forced by my unfailing good manners to watch it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not good. That in a nutshell is all I can say for this video.
# Starting Score: 0.02369922213256359; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  I vowed a long time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of`` Saturday Night Live``. I did n't rent`` Corky Romano`` but I was compulsory by my unfailing good manners to watch it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not good. That in a nutshell is all I can say for this video.
#  Score: 0.03729458525776863
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  I vowed a lange time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of`` Saturday Night Live``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good manners to watch it for media an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not good. That in a nutshell is all I can say for this video.
#  Score: 0.05189899355173111
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  I vowed a lange time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing best manners to watch it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not good. That in a nutshell is all I can say for this video.
#  Score: 0.1623167097568512
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  I vowed a lange time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good manners to monitor it for half an hour. Then my best manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not good. That in a nutshell is all I can tell for this video.
#  Score: 0.2505614161491394
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  I vowed a lange time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good manners to monitor it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not nice. That in a nutshell is all I can tell for this videos.
#  Score: 0.3321456015110016
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  I vowed a lange time ago to NEVER, EVER watch a cinema that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good how to monitor it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not nice. That in a nutshell is all I can tell for this videos.
#  Score: 0.4635786712169647
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  I vowed a lange time formerly to NEVER, forever watch a cinema that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good how to monitor it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not nice. That in a nutshell is all I can tell for this videos.
#  Score: 0.510646402835846
#
# %total_time = 1602 seconds
#
#
# ####################ATTACK 8/25:####################
# Original sentence:
# This is a silly spoof of private eye thrillers as a novelist(Michael Cain)is called upon to 'ghostwrite' an autobiography of a colorful, waning Hollywood star(Mickey Rooney). At times silliness becomes obnoxious. This is not Cain at his best. Rooney is way over the top. Notable support from Lizabeth Scott, Lionel Stander and the comely Nadia Cassini. Not easy to watch.
# Starting Score: 0.07968637347221375; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  This is a silly spoof of private eye thrillers as a novelist( Michael Cain) is called upon to'ghostwrite' an autobiography of a colorful, waning Hollywood star( Mickey Rooney). At times silliness becomes obnoxious. This is not Cain at his best. Rooney is way over the top. Notable support from Lizabeth Scott, Lionel Stander and the comely Nadia Cassini. Not easy to observe.
#  Score: 0.17167948186397552
#
# %generation_time = 143 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  This is a daft spoof of private eye thrillers as a novelist( Michael Cain) is called upon to'ghostwrite' an autobiography of a colorful, waning Hollywood star( Mickey Rooney). At times silliness becomes hateful. This is not Cain at his best. Rooney is way over the top. Notable support from Lizabeth Scott, Lionel Stander and the comely Nadia Cassini. Not easy to observe.
#  Score: 0.7301773428916931
#
# %total_time = 315 seconds
#
#
# ####################ATTACK 9/25:####################
# Original sentence:
# This is the very La Nouvelle Vague.One of the best films of the New Wave and I dare say one of the first ten ever made! Why? The atmosphere, the story,the actors (actress) are all brilliant. This is the theater, a fairy tale, the life, the film.Paris. Thank you Mr.Rivette.
# Starting Score: 0.997246265411377; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. One of the best films of the New Wave and I dare say one of the first ten ever made! Why? The atmosphere, the stories, the actors( actress) are all brilliant. This is the theater, a fairy tale, the life, the film. Paris. Thank you Mr. Rivette.
#  Score: 0.9963240623474121
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. One of the improved films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the actors( actress) are all brilliant. This is the theater, a fairy tale, the life, the movie. Paris. Thank you Mr. Rivette.
#  Score: 0.986194372177124
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. One of the improved films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the agents( actress) are all brilliant. This is the theater, a fairy story, the life, the movie. Paris. Thank you Mr. Rivette.
#  Score: 0.9713261723518372
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. One of the improved films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the agents( actress) are all brilliant. This is the theater, a fairy story, the life, the movie. Paris. thanking you Mr. Rivette.
#  Score: 0.9482824206352234
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. somebody of the improved films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the servants( actress) are all brilliant. This is the theater, a fairy story, the life, the movie. Paris. Thank you Mr. Rivette.
#  Score: 0.92557293176651
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. somebody of the improved films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the servants( actress) are all brilliant. This is the theater, a fairy story, the life, the movie. Paris. acknowledgement you Mr. Rivette.
#  Score: 0.8311988711357117
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #7:
#
# Best Adversarial:
#  This is the very La Nouvelle Vague. somebody of the improved movie of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the officer( actress) are all wondrous. This is the theater, a fairy story, the life, the movie. Paris. Thank you Mr. Rivette.
#  Score: 0.7749013900756836
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  This is the very La Nouvelle Vague. somebody of the improve films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the servants( actress) are all wondrous. This is the theater, a fairy story, the life, the movie. Paris. acknowledgement you Mr. Rivette.
#  Score: 0.4149423837661743
#
# %total_time = 1890 seconds
#
#
# ####################ATTACK 10/25:####################
# Original sentence:
# Outlandish premise that rates low on plausibility and unfortunately also struggles feebly to raise laughs or interest. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's gotta be a contender for an actress who's done so much in her career with very little quality material at her disposal...
# Starting Score: 0.006105566862970591; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  Outlandish premises that rates low on plausibility and unfortunately also struggles feebly to raise laughs or interest. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's got ta be a contender for an actress who's done so much in her career with very little quality material at her disposal...
#  Score: 0.01419258676469326
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  Outlandish premises that rates low on plausibility and unfortunately also struggles feebly to raise laughs or interest. Only Hawn's well-known charm enables it to skate by on very thin ice. Goldie's got ta be a contender for an actress who's done so much in her career with very little quality material at her disposal...
#  Score: 0.02472830004990101
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  Outlandish premises that price low on plausibility and unfortunately also struggles feebly to raise laughs or utility. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's got ta be a contender for an actress who's done so much in her career with very little quality documents at her disposal...
#  Score: 0.0605316087603569
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  Outlandish premises that price low on plausibility and unfortunately also struggles feebly to raises laughs or interest. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's got ta be a contender for an actress who's done so much in her career with very little quality material at her disposition...
#  Score: 0.7051342129707336
#
# %total_time = 945 seconds
#
#
# ####################ATTACK 11/25:####################
# Original sentence:
# My first Fassbinder was a wonderful experience. Film and alternative cinema (small hall, with uncomfortable seats; public had to wait while filmrolls were changed ) were perfect match.There were many cliches used in the film, but Fassbinder presented them so cleverly that I found them really amusing. Sound was also brilliant (sometimes back being louder than dialogue).Everything seemed to be in right place. And I loved the way how after-war-time was presented. Real fun!
# Starting Score: 0.9932411909103394; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  My first Fassbinder was a wonderful experience. Film and alternative cinema( small hall, with uncomfortable seats; public had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so cleverly that I found them really amusing. Sound was also magnificent( sometimes back being louder than dialogue).Everything seemed to be in right place. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.9922161102294922
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  My first Fassbinder was a wonderful experience. Film and alternative cinema( small hall, with uncomfortable seats; public had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so cleverly that I found them really amusing. Sound was also magnificent( sometimes back being louder than dialogue).Everything seemed to be in right place. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.9922161102294922
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  My first Fassbinder was a wonderful experience. Film and alternative cinema( small hall, with uncomfortable seats; public had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so cleverly that I found them really amusing. Sound was also magnificent( sometimes back being louder than dialogue).Everything seemed to be in ok putting. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.9825122356414795
#
# %generation_time = 285 seconds
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  My first Fassbinder was a magnificent experience. Film and alternative cinema( small hall, with uncomfortable seats; public had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly magnificent( sometimes backwards being louder than dialogue).Everything seemed to be in right putting. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.970556378364563
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  My initially Fassbinder was a magnificent experience. Film and alternative cinema( small hall, with uncomfortable seats; public had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly magnificent( occasionally backwards being louder than dialogue).Everything seemed to be in law putting. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.9566097855567932
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  My initially Fassbinder was a marvellous experience. Film and alternative cinema( small hall, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly marvelous( sometimes backwards being louder than dialogue).Everything seemed to be in law putting. And I loved the way how after-war-time was presented. Real fun!
#  Score: 0.9349988698959351
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #7:
#
# Best Adversarial:
#  My initially Fassbinder was a marvellous experience. Film and alternative cinema( small hall, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were many cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly magnificent( sometimes backwards being louder than talking).Everything seemed to be in law putting. And I love the manner how after-war-time was presented. Real fun!
#  Score: 0.8977331519126892
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #8:
#
# Best Adversarial:
#  My initially Fassbinder was a wondrous experiences. Film and alternative cinema( small hall, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were multiple cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly magnificent( sometimes backwards being louder than talking).Everything seemed to be in law putting. And I loved the manner how after-war-time was presented. Real fun!
#  Score: 0.8260624408721924
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #9:
#
# Best Adversarial:
#  My initially Fassbinder was a marvellous experience. Film and alternative cinema( small auditorium, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were multiple cliches used in the film, but Fassbinder presented them so wisely that I found them really amusing. Sound was similarly magnificent( sometimes backwards being louder than talking).Everything seemed to be in law putting. And I cared the manner how after-war-time was gave. Real fun!
#  Score: 0.747748851776123
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  My initially Fassbinder was a wondrous experience. Film and alternative cinema( small auditorium, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were multiple cliches utilised in the film, but Fassbinder presented them so wisely that I discovered them really amusing. Sound was similarly magnificent( sometimes backwards being louder than talking).Everything seemed to be in law putting. And I cared the manner how after-war-time was gave. Real fun!
#  Score: 0.4761296212673187
#
# %total_time = 2467 seconds
#
#
# ####################ATTACK 12/25:####################
# Original sentence:
# I love this Disney Movie! Its a real cute movie, and when it comes on again, I will have to make a mental note to tape it. I really like how they break into the bank trying to find Susie's parents information. You should really see this movie. Its great for the whole family.
# Starting Score: 0.9862053990364075; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mental note to tape it. I really like how they break into the bank trying to find Susie's parents information. You should really see this movie. Its great for the whole family.
#  Score: 0.9783725142478943
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mental note to tape it. I really like how they break into the bank trying to find Susie's parents information. You should frankly see this movie. Its grand for the whole family.
#  Score: 0.8938120007514954
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mental note to tape it. I really like how they break into the bank attempt to find Susie's parents information. You should frankly see this movie. Its large for the whole family.
#  Score: 0.7354177832603455
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mental note to tape it. I really like how they break into the bank attempt to find Susie's parents information. You should frankly see this movie. Its large for the whole family.
#  Score: 0.7354177832603455
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mentally note to tape it. I really like how they break into the bank trying to find Susie's parents information. You should frankly look this movie. Its large for the whole family.
#  Score: 0.732839822769165
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mentally note to tape it. I honestly like how they break into the bank trying to find Susie's parents information. You should frankly see this movie. Its large for the whole family.
#  Score: 0.6430057883262634
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  I love this Disney Movie! Its a factual cute movie, and when it comes on again, I will have to make a mentally note to tape it. I honestly like how they break into the bank attempt to find Susie's parents information. You should frankly ver this movie. Its large for the whole family.
#  Score: 0.48174265027046204
#
# %total_time = 1608 seconds
#
#
# ####################ATTACK 13/25:####################
# Original sentence:
# I bought this DVD after seeing it highly ranked here. It's just a short 20 minutes zombie film. Nothing special about it except for the music perhaps.Don't buy it! Not even really worth spending 20 minutes to see it. Only if you're really bored...
# Starting Score: 0.020081596449017525; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  I bought this DVD after seeing it highly ranked here. It's just a short 20 minutes zombie film. Nothing special about it except for the music perhaps. Do n't buy it! Not again really worth spending 20 minutes to see it. Only if you're really bored...
#  Score: 0.04838431626558304
#
# %generation_time = 143 seconds
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  I bought this DVD after seeing it highly ranked here. It's just a short 20 minutes zombie film. Nothing specially about it except for the music perhaps. Do n't buy it! Not even really worth spending 20 minutes to see it. Only if you're really drilled...
#  Score: 0.11111746728420258
#
# %generation_time = 287 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  I bought this DVD after seeing it highly ranked here. It's just a succinct 20 minutes zombie film. nothin specially about it except for the music perhaps. Do n't buy it! Not even really worth spending 20 record to see it. Only if you're really bored...
#  Score: 0.5305318832397461
#
# %total_time = 489 seconds
#
#
# ####################ATTACK 14/25:####################
# Original sentence:
# I've long heard that to get their start in 'legitimate' films, many behind-the-camera types work on porno films.The people who produced and directed this monstrosity stayed too long.Poorly paced, staged and written, it uses a lot of perfectly good talent (Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line...You'll still want to shower afterwards, though.
# Starting Score: 0.09642938524484634; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  I've long heard that to get their start in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and directed this monstrosity stayed too long.Poorly paced, staged and writes, it uses a lot of perfectly good talent( Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line... You'll still want to shower afterwards, though.
#  Score: 0.1638789027929306
#
# %generation_time = 143 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  I've long heard that to get their start in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and directed this monstrosity stayed too long.Poorly paced, staged and writes, it uses a lot of perfectly good talent( Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the foreigners creature, but it never crosses the line... You'll yet want to shower afterwards, though.
#  Score: 0.29517173767089844
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  I've long heard that to get their launch in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and aimed this monster stayed too long.Poorly paced, staged and writes, it uses a lot of perfectly good talent( Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line... You'll yet want to shower afterwards, though.
#  Score: 0.3108823001384735
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  I've long heard that to get their launch in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and aimed this monstrosity stayed too long.Poorly propelled, staged and writes, it uses a lot of perfectly good talent( Diehl, Dorn, Eggert) badly.Much sexual operations is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line... You'll yet want to shower afterwards, though.
#  Score: 0.4304836690425873
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  I've long heard that to get their launches in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and aimed this creature stayed too long.Poorly propelled, staged and writes, it uses a lot of perfectly good talents( Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line... You'll yet want to shower afterwards, though.
#  Score: 0.5347465872764587
#
# %total_time = 1034 seconds
#
#
# ####################ATTACK 15/25:####################
# Original sentence:
# Not that I dislike childrens movies, but this was a tearjerker with few redeeming qualities. M.J. Fox was the perfect voice for Stuart and the rest of the talent was wasted. Hugh Laurie can be amazingly funny, but is not given the chance in this movie. It´s sugar-coated sugar and would hardly appeal to anyone over 7 years of age. See Toy Story, Monsters Inc. or Shrek instead. 3/10
# Starting Score: 0.15303021669387817; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  Not that I dislike childrens cinematic, but this was a tearjerker with few redeeming qualities. M. J. Fox was the perfect voice for Stuart and the rest of the talent was wasted. Hugh Laurie can be amazingly funny, but is not given the chance in this movie. It´ s sugar-coated sugar and would hardly appeal to anyone over 7 years of age. See Toy Story, Monsters Inc. or Shrek instead. 3/ 10
#  Score: 0.3850668668746948
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  Not that I dislike childrens cinematic, but this was a tearjerker with few redeeming qualities. M. J. Fox was the perfect voice for Stuart and the rest of the talent was wasted. Hugh Laurie can be amazingly funny, but is not given the chance in this movie. It´ s sugar-coated sugar and would hardly appeal to everyone over 7 years of age. consult Toy Story, Monsters Inc. or Shrek instead. 3/ 10
#  Score: 0.5845805406570435
#
# %total_time = 172 seconds
#
#
# ...
# Starting Score: 0.004639218095690012; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so little attachment to characters. Seldom have I been made to cringe by such dire dialogue. Nauseous London thirty-somethings mincing round lurid BBC sets spouting platitudinous mulch. Avoid this cinematic as if it were your grandmother's clunge.
#  Score: 0.00712012080475688
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so little attachment to characters. Seldom have I been made to cringe by such dire dialogue. Nauseous London thirty-somethings mincing round lurid BBC sets blabbering platitudinous mulch. preventing this cinematic as if it were your grandmother's clunge.
#  Score: 0.021381346508860588
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so little enclosure to characters. Seldom have I been introduced to cringe by such dire dialogue. Nauseous London thirty-somethings mincing round lurid BBC sets blabbering platitudinous mulch. averted this cinematic as if it were your grandmother's clunge.
#  Score: 0.11593667417764664
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so little enclosure to characters. Seldom have I been introduced to cringe by such dire dialogue. Nauseous London thirty-somethings mincing round lurid BBC sets prattling platitudinous weed. preventing this cinematic as if it were your grandmother's clunge.
#  Score: 0.1371658444404602
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so little enclosure to characters. Seldom have I been introduced to weep by such dire dialogue. Nauseous London thirty-somethings mincing tower lurid BBC sets prattling platitudinous weed. preventing this cinematic as if it were your grandmother's clunge.
#  Score: 0.3357739746570587
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  The daytime TV of films. Seldom have I felt so modest enclosure to character. Seldom have I been introduced to weep by such dire dialogue. Nauseous London thirty-somethings mincing round lurid BBC sets prattling platitudinous weeds. preventing this cinematic as if it were your grandmother's clunge.
#  Score: 0.44324836134910583
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  The daytime TV of films. Seldom have I felt so little enclosure to character. Seldom have I been introduced to weep by such dire dialogue. Nauseous London thirty-somethings mincing tower lurid BBC sets prattling platitudinous herb. preventing this cinematic as if it were your grandmother's clunge.
#  Score: 0.5445678234100342
#
# %total_time = 1656 seconds
#
#
# ####################ATTACK 23/25:####################
# Original sentence:
# This is my favorite show. I think it is utterly brilliant. Thanks to David Chase for bringing this into my life.Season 11. The Sopranos: 5/52. 46 Long: 4.5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4.5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4.5/510. A Hit Is a Hit: 3.5/511. Nobody Knows Anything: 5/512. Isabella: 5/513. I Dream of Jeannie Cusamano: 5/5
# Starting Score: 0.9959474205970764; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  This is my favorite show. I think it is utterly magnificent. Thanks to David Chase for bringing this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A Hit Is a Hit: 3. 5/511. Nobody Knows Anything: 5/512. Isabella: 5/513. I Dream of Jeannie Cusamano: 5/5
#  Score: 0.9777437448501587
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  This is my favorite show. I think it is utterly magnificent. Thanks to David Chase for bringing this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A Hit Is a Hit: 3. 5/511. Nobody Knows nothing: 5/512. Isabella: 5/513. I dreamt of Jeannie Cusamano: 5/5
#  Score: 0.9579683542251587
#
# %generation_time = 266 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  This is my favourites show. I thinks it is utterly magnificent. Thanks to David Chase for make this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A Hit Is a Hit: 3. 5/511. Nobody Knows nothing: 5/512. Isabella: 5/513. I Dream of Jeannie Cusamano: 5/5
#  Score: 0.8644362092018127
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  This is my favourites display. I thinks it is utterly magnificent. Thanks to David Chase for make this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A Hit Is a struck: 3. 5/511. Nobody Knows nothing: 5/512. Isabella: 5/513. I Dream of Jeannie Cusamano: 5/5
#  Score: 0.7534552812576294
#
# %generation_time = 285 seconds
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  This is my favourites display. I thinks it is wholly magnificent. Thanks to David Chase for make this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A struck Is a struck: 3. 5/511. Nobody Knows nothing: 5/512. Isabella: 5/513. I Dream of Jeannie Cusamano: 5/5
#  Score: 0.6351128220558167
#
# %generation_time = 286 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  This is my favourites display. I thinks it is utterly magnificent. Thanks to David Chase for produce this into my life. Season 11. The Sopranos: 5/52. 46 Long: 4. 5/53. Denial, Anger, Acceptance: 5/54. Meadowlands: 4/55. College:6. Pax Soprana: 5/57. Down Neck: 4. 5/58. The Legend of Tennessee Moltisanti: 5/59. Boca: 4. 5/510. A Hit Is a struck: 3. 5/511. Nobody sais nothing: 5/512. Isabella: 5/513. I slumber of Jeannie Cusamano: 5/5
#  Score: 0.3826400935649872
#
# %total_time = 1295 seconds
#
#
# ####################ATTACK 24/25:####################
# Original sentence:
# Makes "Invasion USA" look like "Apocalypse Now". This one can only be recommended to US skinheads, John Birch supporters or militia members. The message is very simple : let's shoot them all - gooks, commies, latinos, everything that isn't American.Besides, this is badly acted, badly scripted, badly interpreted, incredibly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there can't be any US torturers because they are the GOOD
# Starting Score: 0.003148233750835061; Original Label: 0; Target Label: 1
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommended to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, commies, latinos, everything that is n't American. Besides, this is badly acted, badly scripted, badly interpreted, incredibly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, apologise, there ca n't be any US torturers because they are the GOOD
#  Score: 0.004170331638306379
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt acted, badly scripted, badly interpreted, incredibly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.008767622523009777
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt acted, badly scripted, hurt interpreted, incredibly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.019433483481407166
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #4:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, badly scripted, hurt interpreted, incredibly stupid but no enjoyable at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.036194346845149994
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #5:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, hurt scripted, hurt interpreted, incredibly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.06863460689783096
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #6:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, hurt scripted, hurt interpreted, incredibly stupid but no enjoyable at all. This cinematic could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.21296460926532745
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #7:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia members. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, hurt scripted, hurt regarded, hugely stupid but no enjoyable at all. This movie could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.2152155488729477
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# Generation #8:
#
# Best Adversarial:
#  Makes`` Invasion USA`` see like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia limbs. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, hurt scripted, hurt interpreted, incredibly stupid but no enjoyable at all. This cinematic could be used as a toorture device by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.32600805163383484
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #9:
#
# Best Adversarial:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch supporters or militia limbs. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, wounding scripted, hurt interpreted, incredibly stupid but no enjoyable at all. This cinematic could be used as a toorture devices by CIA torturers. oops, apologise, there ca n't be any US torturers because they are the GOOD
#  Score: 0.4960869550704956
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  Makes`` Invasion USA`` look like`` Apocalypse Now``. This one can only be recommend to US skinheads, John Birch followers or militia limbs. The message is very simple: let's shoot them all- gooks, communist, latinos, everything that is n't American. Besides, this is hurt served, hurt scripted, hurt interpreted, incredibly stupid but no enjoyable at all. This cinematic me be used as a toorture devices by CIA torturers. oops, sorry, there ca n't be any US torturers because they are the GOOD
#  Score: 0.5612956285476685
#
# %total_time = 2570 seconds
#
#
# ####################ATTACK 25/25:####################
# Original sentence:
# This film very succeed in the Film festival in Karlovy Vary, Czech rep. Logically. It' s based on a very good book, excellent actors, good camera, the best director and ICELANDIC. It was probably the most black comedy I've seen.I really DO recommend it to you.
# Starting Score: 0.9529852867126465; Original Label: 1; Target Label: 0
#
# Generating population...
#
# Generation #1:
#
# Best Adversarial:
#  This film very succeed in the Film festival in Karlovy Vary, Czech rep. Logically. It' s based on a very good book, wonderful actors, good camera, the best director and ICELANDIC. It was probably the most black comedy I've seen. I really DO recommend it to you.
#  Score: 0.93238365650177
#
# %generation_time = 142 seconds
#
# Regenerating population...
#
# Generation #2:
#
# Best Adversarial:
#  This film very succeed in the Film festival in Karlovy Vary, Czech rep. Logically. It' s based on a very decent book, wonderful actors, good camera, the higher director and ICELANDIC. It was probably the most black farce I've seen. I really DO recommend it to you.
#  Score: 0.7519599199295044
#
# %generation_time = 284 seconds
#
# Regenerating population...
#
# Generation #3:
#
# Best Adversarial:
#  This film very succeed in the Film festival in Karlovy Vary, Czech rep. soundly. It' s based on a very good book, wonderful actors, good camera, the higher director and ICELANDIC. It was probably the most black farce I've seen. I really DO recommendation it to you.
#  Score: 0.5751158595085144
#
# %generation_time = 285 seconds
#
# Regenerating population...
#
# ATTACK SUCCESS!!!
#
# Final adversarial sentence:
#  This film very succeed in the Film festival in Karlovy Vary, Czech rep. Logically. It' s basis on a very good book, wonderful actors, good camera, the higher director and ICELANDIC. It was probably the most black farce I've seen. I frankly DO recommendation it to you.
#  Score: 0.4501921236515045
#
# %total_time = 770 seconds

# %%
print(final_list)
# Out:
# [('This movies could cure sleep disorders, dont how bad it is. The story dragged, and the naughty guy is not that scary. You will not even see this one on TBS reruns. This film delivered me wonder about Chuck film choices. He work on a real dog with this one.', 0), ("The trailers get you to the movie, but the movie just was n't worth my 8. 50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they had n't added this one to their resume's. To be honest, the book is enhanced..", 0), ("The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this cinematic work if the`` foul duckling`` was really repellant? When will Hollywood stop with this hypocrisy? In my opinion, despite the message that it wants to convey, this movie is pure grotesque.", 0), ('Worst pile of mania to today! Everyone involved with this constructive should be ashamed of themselves. Not one single aspect of the cinema was nothin somewhat love an introductory idea. A premiere grader dis you a stories about pan time is more hilarious.', 0), ("I think that the movies was frankly good. Subject, acting and Nusrat Fateh ALi Khan's music were marvellous. Although the director has succeeded in showing the status of women in rural areas and how they suffer at the manos of male-dominated culture, he has omitted Phoolan's character a bit and has focussed more on the violence faced by her.", 1), ('What more can you ask for? A great screenplay based on one of the nicest plays of the latter half of the 20th century, two fine emotional performances by Courtney and Finney, a realistic vision of war time london, a grand aid blown. This film takes you on an emotional rollercoaster through travesty, sadness, wasting and fulfillment. if you are in the theatre it is even more efficiency. This is a true 10 on the rating scale!', 1), ("I vowed a lange time formerly to NEVER, forever watch a cinema that has ANYONE who EVER was a regular cast member of`` Saturday noche viva``. I did n't rent`` Corky Romano`` but I was forced by my unfailing good how to monitor it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not nice. That in a nutshell is all I can tell for this videos.", 0), ("This is a daft spoof of private eye thrillers as a novelist( Michael Cain) is called upon to'ghostwrite' an autobiography of a colorful, waning Hollywood star( Mickey Rooney). At times silliness becomes hateful. This is not Cain at his best. Rooney is way over the top. Notable support from Lizabeth Scott, Lionel Stander and the comely Nadia Cassini. Not easy to observe.", 0), ('This is the very La Nouvelle Vague. somebody of the improve films of the New Wave and I dare say one of the prima ten ever made! Why? The atmosphere, the stories, the servants( actress) are all wondrous. This is the theater, a fairy story, the life, the movie. Paris. acknowledgement you Mr. Rivette.', 1), ("Outlandish premises that price low on plausibility and unfortunately also struggles feebly to raises laughs or interest. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's got ta be a contender for an actress who's done so much in her career with very little quality material at her disposition...", 0), ('My initially Fassbinder was a wondrous experience. Film and alternative cinema( small auditorium, with uncomfortable seats; pubic had to wait while filmrolls were changed) were perfect match.There were multiple cliches utilised in the film, but Fassbinder presented them so wisely that I discovered them really amusing. Sound was similarly magnificent( sometimes backwards being louder than talking).Everything seemed to be in law putting. A ...

# %%
black_box.evaluate([sent for sent, lab in final_list], [lab for sent, lab in final_list])
# Out:
# 25/25 [==============================] - 0s 7ms/sample - loss: 0.9364 - acc: 0.0000e+00
# [0.9364231824874878, 0.0]

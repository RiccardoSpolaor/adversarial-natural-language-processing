# %%
from utils.seed_setter import set_seed
set_seed()

# %%
import pickle,os
import matplotlib.pyplot as plt
import numpy as np

# %%
negative_experiments_dictionary = {}
positive_experiments_dictionary = {}

# %%
base_dir='./small_adversarial_reviews/'
neg_dir = 'neg/'
pos_dir = 'pos/'

# %%
class Hyperparameter:
    MAX_WORDS = 'maxwords'
    TOP_NEIGHBOURS = 'topneighbours'
    TOP_LM = 'toplm'
    MAX_CHILDREN = 'maxchildren'
    MAX_POP_MEMBERS = 'maxpopmembers'
    
class Result:
    EVALUATION = 'Attack Success'
    TIME = 'Time'
    GENERATIONS = 'Generations'

# %%
def open_pickle_file(name, maxwords, topneighbours, toplm, maxchildren, maxpopmembers):    
    with open(os.path.join(base_dir + neg_dir + 'maxwords{}_topneighbours{}_toplm{}_maxchildren{}_maxpopmembers{}.pickle'.format(
        maxwords, 
        topneighbours, 
        toplm,
        maxchildren,
        maxpopmembers
    )), 'rb') as f:
        negative_experiments_dictionary[name] = pickle.load(f)
    f.close()
    
    with open(os.path.join(base_dir + pos_dir + 'maxwords{}_topneighbours{}_toplm{}_maxchildren{}_maxpopmembers{}.pickle'.format(
        maxwords, 
        topneighbours, 
        toplm,
        maxchildren,
        maxpopmembers
    )), 'rb') as f:
        positive_experiments_dictionary[name] = pickle.load(f)
    f.close()

# %%
open_pickle_file('base', 5, 10, 4, 2, 5)
open_pickle_file('maxwords10', 10, 10, 4, 2, 5)
open_pickle_file('maxwords15', 15, 10, 4, 2, 5)
open_pickle_file('topneighbours15', 5, 15, 4, 2, 5)
open_pickle_file('topneighbours20', 5, 20, 4, 2, 5)
open_pickle_file('toplm6', 5, 10, 6, 2, 5)
open_pickle_file('toplm8', 5, 10, 8, 2, 5)
open_pickle_file('maxchildren4', 5, 10, 4, 4, 5)
open_pickle_file('maxchildren6', 5, 10, 4, 6, 5)
open_pickle_file('maxpopmembers10', 5, 10, 4, 2, 10)
open_pickle_file('maxpopmembers15', 5, 10, 4, 2, 15)

# %%
negative_experiments_dictionary['base']
# Out:
# {'description': 'Parameters:\n\tMaximum words to try to change per population member: 5\n\tMaximum top neighbours to choose per word to change: 10\n\tMaximum top language model substitutes to choose per word to change: 4\n\tMaximum children per generation: 2\n\tMaximum population members: 5\n',
#  'max_words': 5,
#  'top_neighbours': 10,
#  'top_lm': 4,
#  'max_children': 2,
#  'max_pop_members': 5,
#  'adversarial_list': [('This movies could cure sleep disorders, dont how bad it is. The story dragged, and the naughty guy is not that scary. You will not even see this one on TBS reruns. This film delivered me wonder about Chuck film choices. He work on a real dog with this one.',
#    0),
#   ("The trailers get you to the movie, but the movie just was n't worth my 8.50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they had n't added this one to their resume's. To be honest, the book is enhanced..",
#    0),
#   ("The message of this movie is`` personality is more important than aesthetic``. Jeanine Garofalo is alleged to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks like a model).Now, would this movie work if the`` ugly duckling`` was really repulsive? When will Hollywood stop with this hypocrisy? In my views, despite the message that it wants to convey, this cinematic is simply nutty.",
#    0),
#   ('Worst pile of mania to today! all participation with this productive should be humbled of themselves. Not one exclusive aspect of the cinema was none somewhat like an upfront insights. A premiere grader dis you a tale about pan moments is more hilarious.',
#    0),
#   ("I vowed a long time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a usual cast member of`` Saturday evening Live``. I did n't rent`` Corky Romano`` but I was forced by my unfailing best manners to watch it for half an time. Then my finest manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not pleasant. That in a nutshell is all I can tell for this video.",
#    0),
#   ("This is a silly spoof of private eye thrillers as a novelist( Michael Cain) is called upon to'ghostwrite' an autobiography of a colorful, waning Hollywood star( Mickey Rooney). At times silliness becomes hateful. This is not Cain at his best. Rooney is way over the superior. Notable helps from Lizabeth Scott, Lionel Stander and the lithe Nadia Cassini. Not softly to watch.",
#    0),
#   ("Outlandish premises that rate low on plausibility and unfortunately also struggles feebly to raise laughs or interest. Only Hawn's well-known charm allows it to skate by on very thin ice. Goldie's was ta be a contender for an actress who's done so much in her career with very little quality physical at her disposition...",
#    0),
#   ("I bought this DVD after seeing it immensely ranked here. It's just a succinct 20 minutes zombie film. stuff special about it except for the music perhaps.Do n't buy it! Not even indeed valued spending 20 minutes to see it. Only if you're really bored...",
#    0),
#   ("I've long heard that to get their start in'legitimate' films, many behind-the-camera types works on porno films.The people who produced and directed this monster stayed too long.Poorly paced, staged and written, it uses a lot of perfectly best talent( Diehl, Dorn, Eggert) badly.Much sexual actions is teasingly implied here by the brassiere-popping host to the stranger beast, but it never crosses the line... You'll still want to shower afterwards, though.",
#    0),
#   ('Not that I hatred childrens movies, but this was a tearjerker with few redeeming qualities. M. J. Fox was the flawless voice for Stuart and the rest of the talent was missed. Hugh Laurie can be amazingly funny, but is not given the chance in this movie. It´ s sugar-coated sugar and would hardly appeal to anyone over 7 years of age. See Toy Story, Monsters Inc. or Shrek instead. 3/ 10',
#    0),
#   ("I have to admit I've caught this one a few times on the USA Network. There's just thing about the, best, merely insanity of this cinematic which makes me want to watch it once it's on. jah, you're right about the sub-par acting, the plot which only an seven year vecchio could like, etc. But I ca n't help feeling compassionate toward some of the actors. Then again, a few of these actors signed up for the even more gruesome sequel.",
#    0),
#   ('I am a fan of the Nightmare series but this one is gruesome. The deaths are so contemporary. If you were to watch this 20 years later the whole nintendo scene is outdated. I did like the memorabilia. I think they should have just made a prequel about when he was still vivid. That would have been more thrilling. This is a movie you can pick or leave. Depends on how much alternative time you have.',
#    0),
#   ("I could n't believe this was the same chief as Antonia's Line.This film has it all, a pesky graph, disjointed memories, a subplot that has nothing to do with the main plot what so always, and perfectly unimportant features. It was tough to watch. Soooo, meticulous.",
#    0),
#   ('Would someone tell shaq to stick to what he is good at baseball. This movie was not yet hilarious on a daft level. In this movie shaq plays a brilliance who vie in a boom box is that not orginal a genie in a boom box nonetheless of a lamp. He is supposed to help a little boy played by the equally annoying francais cappra. This movies had the most fragile scenario since water world, the acting was ghastly and I think that anyone who likes this flim would be afraid to admit it.',
#    0),
#   ("The daytime TV of films. Seldom have I felt so little attachment to characters. rare have I been executed to cringe by such harrowing dialogue. Nauseous London thirty-somethings cut tour saucy BBC sets rant platitudinous turf. prevention this cinematic as if it were your grandmother's clunge.",
#    0),
#   ("Makes`` Invasion USA`` look loved`` grip Now``. This one can only be recommended to US skinheads, John Birch supporters or posse members. The message is very simple: let's kills them all- gooks, commies, latinos, everything that is n't American.Besides, this is hurt acted, hurt scripted, badly interpreted, hugely stupid but no entertainment at all. This films could be used as a toorture device by CIA torturers. oops, apologize, there ca n't be any US torturers because they are the GOOD",
#    0),
#   ("I do n't see why everyone loves this film so much. True, it does have good intentions and senses, but you can not rewarded for such a weak script. Woody Allen is a brilliant filmaker, but I'm fear this is just a piece of garbage. It's immensely anticipated and the subject topic is all too visible. I happen to be a huge Woody Allan fan and love most of his work, but this I can not recomend.",
#    0),
#   ("I was really watching forward to this movie grounded on the previews and press it received, but after viewing it I was terribly disillusioned. Slums is a perfectly unfunny flick blend with a Todd Solondz type of disturbing family practical sans Todd's brand of humor. The story drags along and each scene is hardest than the last. may I missed the point, but if this film is an example of every girl's growing up experience I am glad to be a man.",
#    0),
#   ('If there was a God, he were have made sure this cinematic stayed in the toilet were it was crapped up. This is BY highly the toughest vampire movies I have ever observed. I may never monitors a vampire film again because of this movie. It brings Zombie Lake look like The Sound of Music.',
#    0),
#   ("I thought the all joke of the movie would be to see some richer white guy acting like Chris Rock, and then see Chris Rock react to peoples's reactions. Instead you just see Chris Rock being himself and people not understanding him. There are likely 2 scenes in the entire movie where they use their ruse. This should have been a lot enhanced.",
#    0),
#   ("The movie includes a very succinct movies of Deneuve in a bathtub. She looks absolutely amazing for a mme age 56, but this is the only saving grace of the movies. Otherwise, it has a foolish, unmotivated script and the lead actress has none of Deneuve's resort. The chef apparently encountered too numerous Peter Greenaway films and Pola X comes across as a student's imitation of the Greenaway style, without any of his inspiration.",
#    0),
#   ("Superdome is one of those movies that gives you wonder why it was executed. The overall parcel concerns someone trying to sabotage the superbowl, and all the attempts made to stop them. How Tom Selleck and Donna Mills' careers managed to survive this is beyond me. However, the most vexing aspect about it was THERE WAS NO FOOTBALL IN IT AT ALL! prevent this one if perhaps.",
#    0),
#   ("This cinematic blows. grotesque`` school`` athmosphere, amazing trainees that are very wicked and behave love criminals but then later after the`` good teacher`` Nick Nolte learning them they became as good and as quiet as kittens.If this cooperation for you, it does n't for me. 0 out of 10",
#    0),
#   ("This crew-versus-monsta has been done a hundred times, sometimes better. This one was pretty slow-moving; only the monster's resurrection was truly cherished. seeks at character developments gets botched by routine. Yeah,`` everyday`` is the word. visited straight to video in France. No wonder",
#    0),
#   ("I was awaits this would be a best weekend vehicle for Tim Curry, one of my all-time favorite performers. Alas and alack, it is NOT. There does n't appear to be any chemistry between anyone on the exhibit, the talks is decidedly unimpressive, and yet the laugh track appeared to be laboring. Brutal.",
#    0),
#   ("Nine minutes of psychedelic, pulsating, traditionally symmetric abstract images, are very to drive anyone crazy. I did spot a full-frame eye at the start, and later some birds silhouetted against other colors. It was just not my cass of tea. It's about 8½ record too long.",
#    0),
#   ('Most surely the worst Columbo ever dreamt up. No murder and the abandonment of the tried and tested formula delivers this a real drag. Falk looks bored throughout and so will you be if you waste anytime vista this.',
#    0),
#   ("This movie was definitely not one of Mary-Kate and Ashley's best movies. I really did n't like it, and I was kind of disappointed in that movie. For some reason, it seemed like it was a cinematic that they put joint really fast. In some parts, it got so pesky that I had to fast forward it. It did n't have any bloopers or any exciting parts like their other movies.",
#    0),
#   ("I believe that this is a discouraging sequel. I miss a lot of the old characters( King Gator, Anne Marie, etc. ), and I do n't like it due to the fact that not even media of the original voices are back to do the characters. A lot of personality was lost in Charlie, and the villain Red is not also half as wicked as Carface was in the first one. If you're a big ADGTH fan loved I am, it's worth see just to admire how the story is nonstop, but do n't count on it being 5 stars in your book.",
#    0),
#   ('Seagal needs to get back to basics breaking bones and kicking butt. No more of this lento motion shit loved foreigner and in the shadows fight like half past dead. Exit casualty showed more of his fighting skills with some wires which was ok but then he went back to ii cinematic directors.',
#    0),
#   ("This film is all right, somewhat silly and to be taken lightly. But what I ca n't stand are the numerous heroes and that boy's ILLEGALY SENTIMENTAL comment near the end:`` look, they all look the same``. Is n't that by far passing the good taste standards? I thinks it was revolting, as were the heroic, unselfish acts by some of the people in this film. I'm not say it wo n't happen like that, but zooming in on all the bravery like that brings my gut churn.",
#    0),
#   ("This has an interesting, albeit somewhat fanciful sci-fi plot, but it's lost with poor direction and shlocky special effects. Rae Dawn Chong is appealing, despite the shortage of a reliable story and direction consistent with her talent.",
#    0),
#   ("Surely this deserves to be in the kick 10 cinema of all time, worth it's just a TV movie. Rubbish that only we British can produce! It perhaps has some merit in the so awful it's good scale. Watch out for scene where they start dancing!",
#    0),
#   ("Low budget horror about an evil force. Hard to believe in this day and age, but way back when this stuff truly utilizing to get theatrical releases! These days this sort of thing should or go direct-to-video or straight to cable. Should n't be too hard to avoid this one; who's ever heard of it?",
#    0),
#   ('The English translations of the titles on the DVD prints of this film is`` Graveyard of Horrors,`` but I think that must be an errors. It should have been called`` Graveyard of Horribles.`` Horrible acting, gruesome editing, grisly story, and horrific music all bringing this a grisly cinematic finest left in a horrific graveyard.Horrible.',
#    0),
#   ("Lolita is a rebel and she's going to share to our wide open eyes some little sex stories, between sci-fi and fantasy... Well, this Surrender Cinema production is not very good: very bad acting, horrifying music and a story line without any story and any line. BUT, the sex scenes are pretty well done, lot of lesbian scenes, and Jacqueline Lovell, as beautiful as in The Exotic House Of Wax, offer to us a very good ultimate and very hot strip show. For Lovell's fans only.",
#    0),
#   ("Okay, I realize that there are some interview Thomas's out there... I was one of them... but then I saw this masterpiece of celluloid.All I can say is that the scene in which George Wendt gets sought out of the spaceship BY HIS A** left me shaking. I sometimes sits bolt riser in my bed, scream loved an former man on a proctologist's table thinking about it. If the chief is reading this... I would pay to be an extra in the sequel.",
#    0),
#   ("Good operators and good performances wo n't conceal a fruitless script, dirty talks, and habits of behavior spiraling into something you'd care about. The most exciting nature is David Berkowitz. No featured development- no growth, no concern, just some suffering for no particular motif, education us nothing and not yet bugging to entertaining.",
#    0),
#   ('Hard up, No proper jobs going down at the pit, why not rent your juvenile! DIY pimp story sans the unwarranted sex scenes, and hard core or soft core, so reads like a public information film from the fifties, give this a wide miss, use a barge pole if you can.',
#    0),
#   ("But I got over it. To me, it seemed that even the Author of the book favored Caroline. I felt so sorry for the character Louise, and she was constantly compared with Esau who was evil, I just found the comparison was a bit tough and un-realistic. genuinely though, the movie was mala. I would n't really see it once you're ready for a big let down.",
#    0),
#   ("There's only one thing I need to say about this movie- the scene where Shaq is in a musical number with Francis Capra's character about wanting to be a genie; never see this movie. The story is ghastly, the acting is terrifying( c'mon, it's Shaq!) and I'd rather see Capra in Free Willy( equally gruesome) twice before ever seeing this cinematic.",
#    0),
#   ("This cinematic scent majorly. The only reason I gave it a 3 was because the graphics were semi delightful. It's full disregard for a plot and the lack of even petty surface characteristic progress made it seem like just a bunch of pleasurable drawings. This is by far THE hardest anime that came out of Japan. I ca n't believe they actually put their names on this refuse. What a crying off selling this aspect for$ 20. If you have n't seen this do n't bother. If you have, I valued you.",
#    0),
#   ('It was repulsive and challenging. What a trash of a fashioned! I vowed, the audience( 1/ 2 full) ri TWICE in 90 mn. This is not a lie. Do not even rent it. Zeta Jones was just too entail to be authoritative. Cusack was fine. Just OK. I perceived apology for him( the actor) in situations people remembering this mess.Roberts was the same as she consistently is. delightful and sweet, but with no goals. The`` romance`` with John was absolutely amazing.',
#    0),
#   ('I usually like hongkong- martial arts- fantasy movies but I hated this one. Once Upon A Time In China, Shogun Assassin, A Chinese spook Story and even Big Trouble In Little China are my favorites but this film sucked! Too much elegant tricks and daft story.4/ 10',
#    0),
#   ("Well I'd have to say that I do own this film and I only like the ending. The cinematic is pesky and slow but the ultimate fight is so hilarious. Lets just say that if the fake bird did n't attack the major evil guy this movie would be a 0 out of 10. The bird though makes it a 3. If you are truly bored or want nothing terrifying to watch rent this and fast forward to the final battle.",
#    0),
#   ("`` Smithereens`` is the kind of worthless movies which just hangs out among the cord channels takes up space like a cheesy dime novel in the public librarian. A needless bit of tripe and first initiative for middling chief Seidelman, the film is fraught with bad acting, naughty sound, bad camera work, and poor quality in all aspects of the film. Many best films never make it to marketplace and why junk flicks like this one do and never seem to go away is one of life's marvelous mysteries. ( D-)",
#    0),
#   ("I have n't seen all Cage's collaboration by any means but his behaved in this one was truly horrifying. The other features manage the gamut of skill but, having most of the emotional scenes, Cage's scenes are just inconvenient to surveillance. He's certainly come a lange ways in 12 years.",
#    0),
#   ("I absolutely loathed this movie! I was 9 when I saw it. It is the only movie I have ever walked out of in the theater. My mama, dad, and I all looked at each other during the movie and knew we were wasting our time. This films stole approximately 45 minutes of my life. Everything about it was ridiculous. The entire premise was too warped. Being 9, I was consistently easily entertained. This movie illustrated that I could n't subject myself to anything and still be entertained.",
#    0),
#   ('I could have effected with the seven gunslingers just staying out. This sequel should never have been done, the first did it all and enhanced. The chart was a turkey, the provisional was turkey, the direction, productive, camera works... all turkey. everyone put out this dope should be tarred and feathered. May they not comeback again!',
#    0),
#   ("A actually muddled impenetrable mess. Most things in the film look more or less like 1987, but then there are futuristic things just thrown in, adored the policeman's ray gun. And that car! The steering seemed to be in love with colorful light. The only truly remarkable performance was the female who played Valerie, but since there was no cast listed, I do n't know which actress that was. This one is valued missing. Grade: and",
#    0)],
#  'time_list': [730,
#   43,
#   2231,
#   5437,
#   2619,
#   686,
#   1887,
#   1524,
#   2012,
#   258,
#   3149,
#   1112,
#   3331,
#   2995,
#   2490,
#   3023,
#   1545,
#   2447,
#   1848,
#   1160,
#   1980,
#   2224,
#   2838,
#   1705,
#   3138,
#   1348,
#   1289,
#   387,
#   2666,
#   2195,
#   679,
#   339,
#   339,
#   721,
#   4539,
#   212,
#   1717,
#   5557,
#   1141,
#   932,
#   1381,
#   5610,
#   5518,
#   1204,
#   1551,
#   2995,
#   1829,
#   732,
#   2355,
#   2857],
#  'generations_list': [1,
#   0,
#   4,
#   12,
#   5,
#   1,
#   3,
#   3,
#   4,
#   0,
#   6,
#   2,
#   7,
#   6,
#   5,
#   6,
#   3,
#   5,
#   3,
#   2,
#   4,
#   4,
#   5,
#   3,
#   6,
#   2,
#   2,
#   0,
#   5,
#   4,
#   1,
#   0,
#   0,
#   1,
#   10,
#   0,
#   3,
#   12,
#   2,
#   1,
#   2,
#   12,
#   12,
#   2,
#   3,
#   6,
#   3,
#   1,
#   5,
#   6],
#  'evaluation': 0.0,
#  'positive': 0}

# %%
negative_experiments_dictionary['topneighbours20']
# Out:
# {'description': 'Parameters:\n\tMaximum words to try to change per population member: 5\n\tMaximum top neighbours to choose per word to change: 20\n\tMaximum top language model substitutes to choose per word to change: 4\n\tMaximum children per generation: 2\n\tMaximum population members: 5\n',
#  'max_words': 5,
#  'top_neighbours': 20,
#  'top_lm': 4,
#  'max_children': 2,
#  'max_pop_members': 5,
#  'adversarial_list': [('This film could cure sleep disorders, thats how nasty it is. The story dragged, and the nasty guy is not that scary. You will not even see this one on TBS reruns. This film performed me wonder about Chuck film choices. He work on a real puppy with this one.',
#    0),
#   ("The trailers get you to the movie, but the movie just was n't worth my 8.50.. it has some good effects, but the storyline.. yech, i like tommy lee jones and will smith as actors, they have both done some good films, but i wish they had n't added this one to their resume's. To be honest, the book is enhanced..",
#    0),
#   ("The messenger of this movie is`` personality is more important than beauty``. Jeanine Garofalo is supposed to be the`` ugly duckling``, but the funny thing is that she's not at all ugly( actually she's a lot more attractive than Uma Thurman, the friend who looks love a model).Now, do this movie work if the`` ugly duckling`` was really repulsive? When will Hollywood stop with this hypocrisy? In my views, despite the message that it wants to communicate, this movie is only nutty.",
#    0),
#   ('Worst stacked of mania to date! Everyone implicated with this production should be ridiculed of themselves. Not everybody lonely roles of the cinematic was doin slightly love an indigenous thoughts. A fiirst grader dialogue you a tale about nap time is more hilarious.',
#    0),
#   ("I vowed a long time ago to NEVER, EVER watch a movie that has ANYONE who EVER was a usual cast member of`` Saturday Night lives``. I did n't rent`` Corky Romano`` but I was bound by my unfailing best manners to watch it for half an hour. Then my good manners failed. Stupid, not funny. Tedious, not hilarious. Bad, not nice. That in a concise is all I can say for this video.",
#    0),
#   ("This is a silly spoof of private eye thrillers as a novelist( Michael Cain) is called upon to'ghostwrite' an memories of a colorful, decreasing Hollywood star( Mickey Rooney). At times antics becomes obnoxious. This is not Cain at his greatest. Rooney is way over the top. Notable helps from Lizabeth Scott, Lionel Stander and the comely Nadia Cassini. Not easy to watch.",
#    0),
#   ("Outlandish premise that rates less on plausibility and unfortunately yet struggles feebly to increase laughs or interest. Only Hawn's well- recognised thrilling allows it to skate by on very lean ice. Goldie's got ta be a contender for an agent who's done so much in her career with very few quality material at her elimination...",
#    0),
#   ("I bought this DVD after seeing it highly rated here. It's just a succinct 20 moments zombie film. Nothing special about it except for the music perhaps.Do n't buy it! Not even really worth priced 20 minutes to see it. Only if you're real bored...",
#    0),
#   ("I've long heard that to get their start in'legitimate' films, many behind-the-camera types work on porno films.The people who produced and directed this freak stayed too long.Poorly paced, staged and writes, it uses a batch of perfectly best performers( Diehl, Dorn, Eggert) badly.Much sexual activity is teasingly implied here by the brassiere-popping host to the alien creature, but it never crosses the line... You'll still want to shower afterwards, though.",
#    0),
#   ('Not that I dislike childrens movies, but this was a tearjerker with few redeeming qualities. M. J. Fox was the perfect voice for Stuart and the rest of the talent was missed. Hugh Laurie can be amazingly funny, but is not given the chauncey in this movie. It´ s sugar-coated sugar and would hardly appeal to anyone over 7 years of age. See Toy Story, Monsters Inc. or Shrek instead. 3/ 10',
#    0),
#   ("I have to recognise I've caught this one a few times on the USA Network. There's just any about the, well, strictly stupidity of this cinematic which provides me want to watch it whenever it's on. Yes, you're right about the sub-par acting, the plot which only an seven year old could like, etc. But I ca n't help feeling enjoyable toward some of the actors. Then again, a few of these actors signed up for the even more gruesome sequel.",
#    0),
#   ('I am a fan of the Nightmare series but this one is terrifying. The deaths are so trendy. If you were to watch this 20 years later the whole pokemon scene is antique. I did like the flashbacks. I feel they should have just made a prequel about when he was still alive. That would have been more interesting. This is a movie you can take or leave. draws on how extremely spare time you have.',
#    0),
#   ("I could n't believe this was the same director as Antonia's Line.This film has it all, a drilled plot, contrasting memories, a subplot that has nothing to do with the main plot what so ever, and totally uninteresting features. It was intense to watch. Soooo, intense.",
#    0),
#   ('were someone tell shaq to stick to what he is good at bullitt. This theatre was not so hilarious on a daft level. In this movie shaq plays a genie who lives in a growing box is that not orginal a genie in a growing box also of a lights. He is supposed to help a little boy played by the equally annoying francais cappra. This movie had the most delicate storyline since hydraulic world, the acting was awful and I feel that anyone who likes this flim must be afraid to admit it.',
#    0),
#   ("The daytime TV of films. Seldom have I noticed so few attachment to characters. Seldom have I been executed to cry by such tragic dialogue. Nauseous London thirty- somethings mincing tour lurid BBC sets spouting platitudinous turf. prevention this cinematic as if it were your grandfather's clunge.",
#    0),
#   ("brings`` invades USA`` look liked`` Apocalypse Now``. This one can only be recommended to US skin, John Birch followers or militia members. The message is very straightforward: lets's shoot them all- gooks, commies, latinos, everything that is n't American.Besides, this is wrong acted, ill scripted, seriously interpreted, highly stupid but no fun at all. This movie could be used as a toorture device by CIA torturers. oops, pardon, there ca n't be any US torturers because they are the GOOD",
#    0),
#   ("I do n't see why everyone amar this film so much. True, it does have good intentions and meaning, but you can not compensate for such a flawed script. Woody Allen is a brilliant filmaker, but I'm afraid this is just a piece of garbage. It's extremely awaited and the subject matter is all too visible. I happen to be a huge Woody Allan fan and love most of his work, but this I can not recomend.",
#    0),
#   ("I was really looking forward to this movie based on the previews and press it received, but after viewing it I was terribly disgruntled. Slums is a perfectly dopey film mixed with a Todd Solondz type of disturbing family reality sans Todd's brand of humor. The story drags along and each scene is worse than the last. Maybe I missed the point, but if this film is an occasion of every girl's growing up experience I am glad to be a man.",
#    0),
#   ('If there was a God, he would have achieved sure this movie stayed in the toilet were it was crapped up. This is BY FAR the finest vampire movie I have ever seen. I may never watch a vampire film again because of this movie. It makes Zombie Lake vista liked The Sound of Music.',
#    0),
#   ("I figured the total hilarious of the movie would be to see some rich white guy acting like Chris Rock, and then see Chris Rock react to people's reactions. Instead you just see Chris Rock being himself and people not understanding him. There are likely 2 scenes in the all movie where they use their gimmick. This should have been a lot better.",
#    0),
#   ("The movie contains a very succinct films of Deneuve in a bathtub. She looks absolutely stunning for a lady age 56, but this is the only rescue grace of the movie. also, it has a mindless, unconcerned script and the lead actress has none of Deneuve's appeal. The director naturally watched too many Peter Greenaway films and Pola X comes into as a student's imitation of the Greenaway style, but any of his inspiration.",
#    0),
#   ("Superdome is one of those movies that gives you wonder why it was achieved. The all plot concerns someone trying to sabotage the superbowl, and all the seeking made to stop them. How Tom Selleck and Donna Mills' careers headed to survive this is beyond me. However, the most distressing thing about it was THERE WAS NO FOOTBALL IN IT AT ALL! evita this one if perhaps.",
#    0),
#   ("This cinematic fears. foolish`` school`` athmosphere, fantastic students that are very wicked and behave love criminals but then later after the`` greatest prof`` Nick Nolte taught them they became as good and as serene as kittens.If this works for you, it does n't for me. 0 out of 10",
#    0),
#   ("This crew-versus-monsta has been done a hundred times, sometimes better. This one was perfectly slow- moving; only the monster's resurrection was really worthwhile. seeks at personality developments gets botched by routine. Yeah,`` routine`` is the word. Went squarely to video in France. No wonder",
#    0),
#   ("I was awaiting this was be a good weekly motor for Tim Curry, everyone of my all-time favorite performers. Alas and alack, it is NOT. There does n't seem to be any chemistry between anyone on the show, the talk is decidedly drab, and yet the laugh track talked to be laboring. Brutal.",
#    0),
#   ("Nine minutes of psychedelic, pulsating, often symmetric abstract images, are enough to drive every crazy. I did mancha a full-frame eye at the launching, and later some birds silhouetted against other colors. It was just not my cup of tea. It's about 8½ minutes too lasting.",
#    0),
#   ('Most definitely the greatest Columbo ever dreamt up. No murder and the abandonment of the tried and tested formula makes this a real drag. Falk looks bored throughout and so will you be if you lose anytime watching this.',
#    0),
#   ("This movie was definitely not one of Mary- Kate and Ashley's best movies. I really did n't like it, and I was kind of disappointed in that movie. For some reason, it seemed like it was a movie that they put together really fast. In some pieces, it got so piercing that I had to fast forward it. It did n't have any bloopers or any exciting sides like their other movies.",
#    0),
#   ("I think that this is a sad sequel. I mme a lot of the old characters( King Gator, Anne Marie, etc. ), and I do n't like it due to the fact that not even half of the natives voices are rear to do the characters. A lot of personality was lost in Charlie, and the villain Red is not even half as dirty as Carface was in the prime one. If you're a big ADGTH fan love I am, it's worth seeing just to see how the story is continued, but do n't countdown on it being 5 stars in your book.",
#    0),
#   ('Seagal needs to get back to basics breaking bones and kicking butt. No more of this slow request shit like foreign and in the darker fighting like half past dead. Exit wounds showed more of his fighting skills with some wires which was fine but then he came back to b cinematic directors.',
#    0),
#   ("This film is all right, fairly silly and to be taken lightly. But what I ca n't stand are the numerous heroes and that boy's ILLEGALY SENTIMENTAL comment near the end:`` look, they all look the same``. Is n't that by far passing the good tasty standards? I thought it was revolting, as were the heroic, unselfish acts by some of the people in this film. I'm not saying it wo n't happen like that, but zooming in on all the bravery enjoy that makes my stomach churn.",
#    0),
#   ("This has an interesting, albeit somewhat inventive sci-fi plot, but it's lost with poor direction and shlocky unique effects. Rae Dawn Chong is thrilling, despite the lack of a believable story and direction consistent with her talent.",
#    0),
#   ("Surely this deserves to be in the bottom 10 films of all time, pity it's just a TV movie. Rubbish that only we British can produce! It perhaps has some merit in the so terrifying it's good scale. Watch out for scene where they start dancing!",
#    0),
#   ("Low budget horror about an evil force. Hard to believe in this day and age, but way back when this stuff really used to get fantastic release! These days this sort of thing would either go direct- to- video or straight to cable. Should n't be too hard to avoid this one; who's ever heard of it?",
#    0),
#   ('The English translation of the title on the DVD printing of this theatre is`` Graveyard of Horrors,`` but I feel that must be an blunder. It should have been called`` Graveyard of Horribles.`` Horrible acting, gruesome editing, horrible story, and terrifying music all creating this a spooky film greatest departure in a terrifying graveyard.Horrible.',
#    0),
#   ("Lolita is a rebel and she's going to share to our wide open eyes some little sex stories, between sci-fi and fantasy... Well, this Surrender Cinema production is not very good: very bad acting, horrifying music and a story line without any story and any line. BUT, the sex scenes are pretty perfectly done, lot of lesbian scenes, and Jacqueline Lovell, as beautiful as in The Exotic House Of Wax, offer to us a very good final and very hot strip show. For Lovell's fans only.",
#    0),
#   ("Okay, I realize that there are some doubting Thomas's out there... I was one of them... but then I saw this masterpiece of celluloid.All I can say is that the movie in which George Wendt gets sought out of the spaceship BY HIS A** left me trembling. I sometimes sit bolt upright in my bed, shout like an old man on a proctologist's table thinking about it. If the chief is reading this... I would lend to be an extra in the aftermath.",
#    0),
#   ("Good companion and best performances ca n't disguise a needless script, dirty dialogue, and patterns of misconduct spiraling into something you'd care about. The most exciting personality is David Berkowitz. No personality development- no growth, no interest, just some suffering for no own motif, school us nil and not till bothering to entertain.",
#    0),
#   ('Hard up, No proper job going down at the pit, why not rent your kids! DIY pimp story without the unreasonable sex scenes, either hard heart or soft core, therefore reads like a public information film from the fifties, give this a wide miss, use a crazy pole if you can.',
#    0),
#   ("But I got over it. To me, it seemed that even the Author of the book favorite Caroline. I felt so sorry for the personality Louise, and she was constantly compared with Esau who was evil, I just felt the comparison was a bit harsh and un-realistic. Really while, the movie was wicked. I would n't really see it unless you're ready for a significant leash down.",
#    0),
#   ("There's only one thing I need to say about this movie- the film where Shaq is in a musical number with Francis Capra's character about wanting to be a genie; never see this film. The story is terrifying, the acting is terrifying( c'mon, it's Shaq!) and I'd rather see Capra in Free Willy( equally terrifying) twice before ever seeing this theatrical.",
#    0),
#   ("This movie feels majorly. The only ground I introduced it a 3 was because the graphics were semi charming. It's together disregard for a parcel and the lack of even minor surface character preparation achieved it seem like just a bunch of nice drawings. This is by highly THE greatest anime that came out of Japan. I ca n't feel they actually put their names on this punk. What a torn off selling this ding for$ 20. If you have n't perceived this do n't bother. If you have, I pity you.",
#    0),
#   ('It was repulsive and poignant. What a waste of a cast! I swear, the populace( 1/2 full) laughed TWICE in 90 minutes. This is not a lie. Do not even rent it. Zeta Jones was just too mean to be believable. Cusack was well. Just OK. I felt pardon for him( the actor) in case people remember this mess.Roberts was the same as she always is. Charming and delightful, but with no targets. The`` romance`` with John was perfectly fantastic.',
#    0),
#   ('I usually like hongkong- martial arts- fantasy movies but I hated this one. Once Upon A Time In China, Shogun Assassin, A Chinese Ghost Story and even grand Trouble In Little China are my favorites but this film sucked! Too very elegant tricks and beast story.4/ 10',
#    0),
#   ("Well I'd have to dis that I do own this film and I only like the ending. The movie is piercing and slow but the final battle is so funny. Lets just say that if the fake bird did n't attack the fundamental evil guy this movie would be a 0 out of 10. The bird though makes it a 3. If you are truly bored or want anything horrific to watch rent this and fast forward to the final battle.",
#    0),
#   ("`` Smithereens`` is the nature of unnecessary flick which just hangs out among the cable channels taking up space like a cheesy coin novel in the public library. A needless bit of tripe and first effort for weaker leiter Seidelman, the theatrical is fraught with negative acting, bad sound, bad camera work, and weak quality in all aspects of the film. Many better films never make it to market and why junk movements loved this one do and never seem to go beyond is one of life's great mysteries. ( D-)",
#    0),
#   ("I have n't seen all Cage's works by any utilities but his acting in this one was truly terrifying. The other characters executed the gamut of ability but, having most of the emotional scenes, Cage's scenes are just embarrassing to watch. He's certainly come a long ways in 12 years.",
#    0),
#   ("I absolutely loathed this movie! I was 9 when I saw it. It is the only movie I have ever walked out of in the theater. My mom, dad, and I all looked at each other during the movie and knew we were wasting our time. This movies stole approximately 45 minutes of my life. Everything about it was ridiculous. The entire premises was too warped. Being 9, I was always easily entertained. This movie proved that I could n't subject myself to anything and still be entertained.",
#    0),
#   ('I could have been with the september gunslingers just stay outside. This sequel should never have been effected, the prime did it all and well. The lots was a turkey, the acting was turkish, the directive, produces, house works... all turkey. Whoever put out this litter should be tarred and feathered. May they not return again!',
#    0),
#   ("A true chaotic incomprehensible desolation. Most things in the film look more or less like 1987, but then there are futuristic things just thrown in, like the policeman's ray gun. And that car! The director seemed to be in love with colored lights. The only truly excellent performance was the girl who played Valerie, but since there was no cast listing, I do n't know which actress that was. This everyone is valuable missing. Grade: F",
#    0)],
#  'time_list': [1726,
#   246,
#   2133,
#   10832,
#   2217,
#   1319,
#   3783,
#   2402,
#   2908,
#   1419,
#   3266,
#   1630,
#   4103,
#   7613,
#   4824,
#   5941,
#   1602,
#   2755,
#   1687,
#   1762,
#   4497,
#   2909,
#   5178,
#   1648,
#   4993,
#   1367,
#   902,
#   1339,
#   5072,
#   3831,
#   804,
#   1283,
#   246,
#   1314,
#   6199,
#   406,
#   3058,
#   12964,
#   1994,
#   3957,
#   2474,
#   6575,
#   5434,
#   1275,
#   2213,
#   6710,
#   1697,
#   1643,
#   4271,
#   3673],
#  'generations_list': [1,
#   0,
#   2,
#   12,
#   2,
#   1,
#   4,
#   2,
#   3,
#   1,
#   3,
#   1,
#   4,
#   9,
#   5,
#   7,
#   1,
#   2,
#   1,
#   1,
#   5,
#   3,
#   5,
#   1,
#   5,
#   1,
#   0,
#   1,
#   5,
#   4,
#   0,
#   1,
#   0,
#   1,
#   7,
#   0,
#   2,
#   13,
#   1,
#   3,
#   2,
#   7,
#   6,
#   1,
#   2,
#   7,
#   1,
#   1,
#   5,
#   4],
#  'evaluation': 0.0,
#  'positive': 0}

# %%
class StatKind:
    MEAN = 'Mean'
    TOTAL = 'Total'

# %%
def get_plot_values(hyperparameter):
    if hyperparameter == Hyperparameter.MAX_WORDS: 
        return ['10', '15']
    elif hyperparameter == Hyperparameter.TOP_NEIGHBOURS: 
        return ['15', '20'] 
    elif hyperparameter == Hyperparameter.TOP_LM: 
        return ['6', '8']
    elif hyperparameter == Hyperparameter.MAX_CHILDREN: 
        return ['4', '6']
    elif hyperparameter == Hyperparameter.MAX_POP_MEMBERS: 
        return ['10', '15']
    else:
        return None

def set_plot_title(stat_kind, result, hyperparameter):
    if stat_kind == StatKind.MEAN:
        return 'Mean {} Results for {}'.format(result, hyperparameter)
    elif stat_kind == StatKind.TOTAL:
        return 'Total {} Results for {}'.format(result, hyperparameter)
    else:
        return '{} for {}'.format(result, hyperparameter)

def get_plot_data (hyperparameter, result, stat_kind, values):
    
    if result == Result.EVALUATION:
        res = 'evaluation'
    elif result == Result.TIME:
        res = 'time_list'
    elif result == Result.GENERATIONS:
        res = 'generations_list'
        
    positive_data = []
    negative_data = []
        
    if stat_kind == StatKind.MEAN:
        positive_data += [sum(positive_experiments_dictionary['base'][res]) / len(positive_experiments_dictionary['base'][res])]
        for value in values:
            positive_data += [
                sum(positive_experiments_dictionary[hyperparameter + value][res]) / len(positive_experiments_dictionary[hyperparameter + value][res])
            ]
        
        negative_data += [sum(negative_experiments_dictionary['base'][res]) / len(negative_experiments_dictionary['base'][res])]
        for value in values:
            negative_data += [
                sum(negative_experiments_dictionary[hyperparameter + value][res]) / len(negative_experiments_dictionary[hyperparameter + value][res])
            ]
            
    elif stat_kind == StatKind.TOTAL:
        positive_data += [sum(positive_experiments_dictionary['base'][res])]
        for value in values:
            positive_data += [sum(positive_experiments_dictionary[hyperparameter + value][res])]
        
        negative_data += [sum(negative_experiments_dictionary['base'][res])]
        for value in values:
            negative_data += [sum(negative_experiments_dictionary[hyperparameter + value][res])]
            
    else:
        positive_data += [(1 - positive_experiments_dictionary['base'][res])*100]
        for value in values:
            positive_data += [(1 - positive_experiments_dictionary[hyperparameter + value][res]) * 100]
        
        negative_data += [(1 - negative_experiments_dictionary['base'][res])*100]
        for value in values:
            negative_data += [(1 - negative_experiments_dictionary[hyperparameter + value][res]) * 100]
            
    return positive_data, negative_data

def value_label(ax, rectangles):
    offset = {'C' : 0, 'R' : 1, 'L' : -1}
    for rect in rectangles:
        height = rect.get_height()
        ax.annotate(
            '{:.2f}'.format(height),
            xy = (rect.get_x() + rect.get_width() / 2, height),
            xytext = (0, 3),
            textcoords = 'offset points',
            ha = 'center', va = 'bottom'
        )

# %%
def plot_parameters(hyperparameter, result, stat_kind = None):
    
    base_values = {
        Hyperparameter.MAX_WORDS: 5,
        Hyperparameter.TOP_NEIGHBOURS: 10,
        Hyperparameter.TOP_LM: 4,
        Hyperparameter.MAX_CHILDREN: 2,
        Hyperparameter.MAX_POP_MEMBERS: 5
    }
    
    values = get_plot_values(hyperparameter)
    
    index = np.arange(3)
    positive_data, negative_data = get_plot_data (hyperparameter, result, stat_kind, values)
    
    fig, ax = plt.subplots(figsize=(15,10))
    
    bar_width = 0.2
    opacity = 0.8
    
    rectangles_1 = plt.bar(index, positive_data, bar_width, color = 'g', label = 'Positive Reviews', alpha = opacity)
    rectangles_2 = plt.bar(index + bar_width, negative_data, bar_width, color = (0.95,0,0), label = 'Negative Reviews', alpha = opacity)
    
    plt.xlabel(hyperparameter)
    
    if result == Result.TIME:
        result_string = result + ' (seconds)'
    elif result == Result.GENERATIONS:
        result_string = result
    elif result == Result.EVALUATION:
        result_string = result + ' (%)'
    
    plt.ylabel('{} {}'.format(stat_kind, result_string) if stat_kind == StatKind.MEAN or stat_kind == StatKind.TOTAL 
               else result_string)
    
    plt.title(set_plot_title(stat_kind, result, hyperparameter))#, fontsize = 16)
    
    plt.xticks(index + bar_width/2, ([base_values[hyperparameter]] + values))
    
    value_label(ax, rectangles_1)
    value_label(ax, rectangles_2)
    
    plt.legend()
    
    plt.show()

# %% [markdown]
# # Dati
#
# I parametri di base considerati sono:
# * max_words: 5,
# * top_neighbours: 10,
# * top_lm: 4,
# * max_children: 2,
# * max_pop_members: 5.
#
# Per ogni parametro sono state previste altre 2 possibili variazioni, lasciando gli altri parametri inalterati.

# %% [markdown]
# ## MAX WORDS

# %% [markdown]
# ### Generations

# %%
plot_parameters(Hyperparameter.MAX_WORDS, Result.GENERATIONS, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_WORDS, Result.GENERATIONS, StatKind.TOTAL)

# %% [markdown]
# ### Time

# %%
plot_parameters(Hyperparameter.MAX_WORDS, Result.TIME, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_WORDS, Result.TIME, StatKind.TOTAL)

# %% [markdown]
# ## Evaluation

# %%
plot_parameters(Hyperparameter.MAX_WORDS, Result.EVALUATION)

# %% [markdown]
# ## TOP NEIGHBOURS

# %% [markdown]
# ### Generations

# %%
plot_parameters(Hyperparameter.TOP_NEIGHBOURS, Result.GENERATIONS, StatKind.MEAN)
#plot_parameters(Hyperparameter.TOP_NEIGHBOURS, Result.GENERATIONS, StatKind.TOTAL)

# %% [markdown]
# ### Time

# %%
plot_parameters(Hyperparameter.TOP_NEIGHBOURS, Result.TIME, StatKind.MEAN)
#plot_parameters(Hyperparameter.TOP_NEIGHBOURS, Result.TIME, StatKind.TOTAL)

# %% [markdown]
# ### Evaluation

# %%
plot_parameters(Hyperparameter.TOP_NEIGHBOURS, Result.EVALUATION)

# %% [markdown]
# ## MAX CHILDREN

# %% [markdown]
# ### Generations

# %%
plot_parameters(Hyperparameter.MAX_CHILDREN, Result.GENERATIONS, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_CHILDREN, Result.GENERATIONS, StatKind.TOTAL)

# %% [markdown]
# ### Time

# %%
plot_parameters(Hyperparameter.MAX_CHILDREN, Result.TIME, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_CHILDREN, Result.TIME, StatKind.TOTAL)

# %% [markdown]
# ### Evaluation

# %%
plot_parameters(Hyperparameter.MAX_CHILDREN, Result.EVALUATION)

# %% [markdown]
# ## TOP LM

# %% [markdown]
# ### Generations

# %%
plot_parameters(Hyperparameter.TOP_LM, Result.GENERATIONS, StatKind.MEAN)
#plot_parameters(Hyperparameter.TOP_LM, Result.GENERATIONS, StatKind.TOTAL)

# %% [markdown]
# ### Time

# %%
plot_parameters(Hyperparameter.TOP_LM, Result.TIME, StatKind.MEAN)
#plot_parameters(Hyperparameter.TOP_LM, Result.TIME, StatKind.TOTAL)

# %% [markdown]
# ## Evaluation

# %%
plot_parameters(Hyperparameter.TOP_LM, Result.EVALUATION)

# %% [markdown]
# ## MAX POP MEMBERS

# %% [markdown]
# ### Generations

# %%
plot_parameters(Hyperparameter.MAX_POP_MEMBERS, Result.GENERATIONS, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_POP_MEMBERS, Result.GENERATIONS, StatKind.TOTAL)

# %% [markdown]
# ### Time

# %%
plot_parameters(Hyperparameter.MAX_POP_MEMBERS, Result.TIME, StatKind.MEAN)
#plot_parameters(Hyperparameter.MAX_POP_MEMBERS, Result.TIME, StatKind.TOTAL)

# %% [markdown]
# ## Evaluation

# %%
plot_parameters(Hyperparameter.MAX_POP_MEMBERS, Result.EVALUATION)
